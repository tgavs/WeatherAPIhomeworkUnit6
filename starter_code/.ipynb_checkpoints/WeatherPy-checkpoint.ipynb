# %% [markdown]
# # WeatherPy
# ----
#
# ### Analysis
# * As expected, the weather becomes significantly warmer as one approaches the equator (0 Deg. Latitude). More interestingly, however, is the fact that the southern hemisphere tends to be warmer this time of year than the northern hemisphere. This may be due to the tilt of the earth.
# * There is no strong relationship between latitude and cloudiness. However, it is interesting to see that a strong band of cities sits at 0, 80, and 100% cloudiness.
# * There is no strong relationship between latitude and wind speed. However, in northern hemispheres there is a flurry of cities with over 20 mph of wind.
#
# ---
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from datetime import date

# Import API key
from api_keys import api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []
# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)   

# Print the city count to confirm sufficient count
print(len(cities))
# Out:
# 602

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
#call example parameters
url = "http://api.openweathermap.org/data/2.5/weather?"
city = "Mexico"
units = "metric"

# %%
# Build query URL and request your results in Celsius
query_url = f"{url}appid={api_key}&q={city}&units={units}"

query_url
# Out:
# 'http://api.openweathermap.org/data/2.5/weather?appid=1205305b6503b5009fc8c436728e1ea8&q=Mexico&units=metric'

# %%
# Get weather data
weather_response = requests.get(query_url)
weather_json = weather_response.json()

weather_json
# Out:
# {'coord': {'lon': -70.55, 'lat': 44.56},
#  'weather': [{'id': 600,
#    'main': 'Snow',
#    'description': 'light snow',
#    'icon': '13n'}],
#  'base': 'stations',
#  'main': {'temp': -4.65,
#   'pressure': 1023,
#   'humidity': 78,
#   'temp_min': -8,
#   'temp_max': -3.3},
#  'visibility': 4828,
#  'wind': {'speed': 3.1, 'deg': 290},
#  'clouds': {'all': 90},
#  'dt': 1545862500,
#  'sys': {'type': 1,
#   'id': 3130,
#   'message': 0.0249,
#   'country': 'US',
#   'sunrise': 1545826684,
#   'sunset': 1545858516},
#  'id': 4971871,
#  'name': 'Mexico',
#  'cod': 200}

# %%
# Get temperature from JSON response
temperature = weather_json["main"]["temp"]
temperature
# Out:
# -4.65

# %%
unit='metric'
i=0
# list for information to gather
temperatures=[]
cloudiness=[]
countries=[]
dates=[]
humidities=[]
lats=[]
lngs=[]
maxTemps=[]
windSpeeds=[]
ctyfound=[]
ctynotfound=[]

# loop throught the list of units and append them to temperatures list
for city in cities:

    # Build query URL based on current element in units
       
    query_url = str(url) + "appid=" + str(api_key) + "&q=" + str(city) + "&units=" + str(unit)
    
    
    i=i+1
    
    try: 
        
        # Get weather data
        weather_response = requests.get(query_url)
        weather_json = weather_response.json()
        
        print(f'Processing Record:Record Number {i}; CityName:{city}')   
        
        # Get data from json file
                
        temperature = weather_json["main"]["temp"]
        cloud=weather_json["clouds"]["all"]
        country=weather_json["sys"]["country"]
        date=weather_json["dt"]
        humidity=weather_json["main"]["humidity"]
        lat=weather_json["coord"]["lat"]
        lng=weather_json["coord"]["lon"]
        maxTemp=weather_json["main"]["temp_max"]
        windSpeed=weather_json["wind"]["speed"]
        
        ctyfound.append(city)
        temperatures.append(temperature)
        cloudiness.append(cloud)
        countries.append(country)
        dates.append(date)
        humidities.append(humidity)
        lats.append(lat)
        lngs.append(lng)
        maxTemps.append(maxTemp)
        windSpeeds.append(windSpeed)
        
    except:
        
        print(f'NOT FOUND...Skipping Record Number {i}; CityName:{city}')
        ctynotfound.append(city)
        
        pass
# Out:
# Processing Record:Record Number 1; CityName:punta arenas; QueryURL=http://api.openweathermap.org/data/2.5/weather?appid=1205305b6503b5009fc8c436728e1ea8&q=punta arenas&units=metric
# Processing Record:Record Number 2; CityName:hobart; QueryURL=http://api.openweathermap.org/data/2.5/weather?appid=1205305b6503b5009fc8c436728e1ea8&q=hobart&units=metric
# Processing Record:Record Number 3; CityName:bluff; QueryURL=http://api.openweathermap.org/data/2.5/weather?appid=1205305b6503b5009fc8c436728e1ea8&q=bluff&units=metric
# Processing Record:Record Number 4; CityName:adzope; QueryURL=http://api.openweathermap.org/data/2.5/weather?appid=1205305b6503b5009fc8c436728e1ea8&q=adzope&units=metric
# Processing Record:Record Number 5; CityName:mataura; QueryURL=http://api.openweathermap.org/data/2.5/weather?appid=1205305b6503b5009fc8c436728e1ea8&q=mataura&units=metric
# Processing Record:Record Number 6; CityName:kaitangata; QueryURL=http://api.openweathermap.org/data/2.5/weather?appid=1205305b6503b5009fc8c436728e1ea8&q=kaitangata&units=metric
# Processing Record:Record Number 7; CityName:vaini; QueryURL=http://api.openweathermap.org/data/2.5/weather?appid=1205305b6503b5009fc8c436728e1ea8&q=vaini&units=metric
# Processing Record:Record Number 8; CityName:busselton; QueryURL=http://api.openweathermap.org/data/2.5/weather?appid=1205305b6503b5009fc8c436728e1ea8&q=busselton&units=metric
# Processing Record:Record Number 9; CityName:rikitea; QueryURL=http://api.openweathermap.org/data/2.5/weather?appid=1205305b6503b5009fc8c436728e1ea8&q=rikitea&units=metric
# Processing Record:Record Number 10; CityName:jamestown; QueryURL=http://api.openweathermap.org/data/2.5/weather?appid=1205305b6503b5009fc8c436728e1ea8&q=jamestown&units=metric
# Processing Record:Record Number 11; CityName:faridpur; QueryURL=http://api.openweathermap.org/data/2.5/weather?appid=1205305b6503b5009fc8c436728e1ea8&q=faridpur&units=metric
# Processing Record:Record Number 12; CityName:ilulissat; QueryURL=http://api.openweathermap.org/data/2.5/weather?appid=1205305b6503b5009fc8c436728e1ea8&q=ilulissat&units=metric
# Processing Record:Record Number 13; CityName:saint-philippe; QueryURL=http://api.openweathermap.org/data/2.5/weather?appid=1205305b6503b5009fc8c436728e1ea8&q=saint-philippe&units=metric
# Processing Record:Record Number 14; CityName:magistralnyy; QueryURL=http://api.openweathermap.org/data/2.5/weather?appid=1205305b6503b5009fc8c436728e1ea8&q=magistralnyy&units=metric
# Processing Record:Record Number 15; CityName:korla; QueryURL=http://api.openweathermap.org/data/2.5/weather?appid=1205305b6503b5009fc8c436728e1ea8&q=korla&units=metric
# NOT FOUND...Skipping Record Number 15; CityName:korla
# Processing Record:Record Number 16; CityName:sao borja; QueryURL=http://api.openweathermap.org/data/2.5/weather?appid=1205305b6503b5009fc8c436728e1ea8&q=sao borja&units=metric
# Processing Record:Record Number 17; CityName:tasiilaq; QueryURL=http://api.openweathermap.org/data/2.5/weather?appid=1205305b6503b5009fc8c436728e1ea8&q=tasiilaq&units=metric
# Processing Record:Record Number 18; CityName:chokurdakh; QueryURL=http://api.openweathermap.org/data/2.5/weather?appid=1205305b6503b5009fc8c436728e1ea8&q=chokurdakh&units=metric
# Processing Record:Record Number 19; CityName:taltal; QueryURL=http://api.openweathermap.org/data/2.5/weather?appid=1205305b6503b5009fc8c436728e1ea8&q=taltal&units=metric
# Processing Record:Record Number 20; CityName:lasa; QueryURL=http://api.openweathermap.org/data/2.5/weather?appid=1205305b6503b5009fc8c436728e1ea8&q=lasa&units=metric
# Processing Record:Record Number 21; CityName:hasaki; QueryURL=http://api.openweathermap.org/data/2.5/weather?appid=1205305b6503b5009fc8c436728e1ea8&q=hasaki&units=metric
# Processing Record:Record Number 22; CityName:port alfred; QueryURL=http://api.openweathermap.org/data/2.5/weather?appid=1205305b6503b5009fc8c436728e1ea8&q=port alfred&units=metric
# Processing Record:Record Number 23; CityName:loandjili; QueryURL=http://api.openweathermap.org/data/2.5/weather?appid=1205305b6503b5009fc8c436728e1ea8&q=loandjili&units=metric
# Processing Record:Record Number 24; CityName:tiksi; QueryURL=http://api.openweathermap.org/data/2.5/weather?appid=1205305b6503b5009fc8c436728e1ea8&q=tiksi&units=metric
# Processing Record:Record Number 25; CityName:alcaniz; QueryURL=http://api.openweathermap.org/data/2.5/weather?appid=1205305b6503b5009fc8c436728e1ea8&q=alcaniz&units=metric
# Processing Record:Record Number 26; CityName:gamba; QueryURL=http://api.openweathermap.org/data/2.5/weather?appid=1205305b6503b5009fc8c436728e1ea8&q=gamba&units=metric
# Processing Record:Record Number 27; CityName:tuatapere; QueryURL=http://api.openweathermap.org/data/2.5/weather?appid=1205305b6503b5009fc8c436728e1ea8&q=tuatapere&units=metric
# Processing Record:Record Number 28; CityName:noumea; QueryURL=http://api.openweathermap.org/data/2.5/weather?appid=1205305b6503b5009fc8c436728e1ea8&q=noumea&units=metric
# Processing Record:Record Number 29; CityName:kiskunfelegyhaza; QueryURL=http://api.openweathermap.org/data/2.5/weather?appid=1205305b6503b5009fc8c436728e1ea8&q=kiskunfelegyhaza&units=metric
# Processing Record:Record Number 30; CityName:puerto cabezas; QueryURL=http://api.openweathermap.org/data/2.5/weather?appid=1205305b6503b5009fc8c436728e1ea8&q=puerto cabezas&units=metric
# Processing Record:Record Number 31; CityName:ondjiva; QueryURL=http://api.openweathermap.org/data/2.5/weather?appid=1205305b6503b5009fc8c436728e1ea8&q=ondjiva&units=metric
# Processing Record:Record Number 32; CityName:petropavlovsk-kamchatskiy; QueryURL=http://api.openweathermap.org/data/2.5/weather?appid=1205305b6503b5009fc8c436728e1ea8&q=petropavlovsk-kamchatskiy&units=metric
# Processing Record:Record Number 33; CityName:kavaratti; QueryURL=http://api.openweathermap.org/data/2.5/weather?appid=1205305b6503b5009fc8c436728e1ea8&q=kavaratti&units=metric
# Processing Record:Record Number 34; CityName:pevek; QueryURL=http://api.openweathermap.org/data/2.5/weather?appid=1205305b6503b5009fc8c436728e1ea8&q=pevek&units=metric
# Processing Record:Record Number 35; CityName:batu; QueryURL=http://api.openweathermap.org/data/2.5/weather?appid=1205305b6503b5009fc8c436728e1ea8&q=batu&units=metric
# Processing Record:Record Number 36; CityName:upernavik; QueryURL=http://api.openweathermap.org/data/2.5/weather?appid=1205305b6503b5009fc8c436728e1ea8&q=upernavik&units=metric
# Processing Record:Record Number 37; CityName:iqaluit; QueryURL=http://api.openweathermap.org/data/2.5/weather?appid=1205305b6503b5009fc8c436728e1ea8&q=iqaluit&units=metric
# Processing Record:Record Number 38; CityName:nome; QueryURL=http://api.openweathermap.org/data/2.5/weather?appid=1205305b6503b5009fc8c436728e1ea8&q=nome&units=metric
# Processing Record:Record Number 39; CityName:aquiraz; QueryURL=http://api.openweathermap.org/data/2.5/weather?appid=1205305b6503b5009fc8c436728e1ea8&q=aquiraz&units=metric
# Processing Record:Record Number 40; CityName:sentyabrskiy; QueryURL=http://api.openweathermap.org/data/2.5/weather?appid=1205305b6503b5009fc8c436728e1ea8&q=sentyabrskiy&units=metric
# NOT FOUND...Skipping Record Number 40; CityName:sentyabrskiy
# Processing Record:Record Number 41; CityName:lazaro cardenas; QueryURL=http://api.openweathermap.org/data/2.5/weather?appid=1205305b6503b5009fc8c436728e1ea8&q=lazaro cardenas&units=metric
# Processing Record:Record Number 42; CityName:kruisfontein; QueryURL=http://api.openweathermap.org/data/2.5/weather?appid=1205305b6503b5009fc8c436728e1ea8&q=kruisfontein&units=metric
# Processing Record:Record Number 43; CityName:burns lake; QueryURL=http://api.openweathermap.org/data/2.5/weather?appid=1205305b6503b5009fc8c436728e1ea8&q=burns lake&units=metric
# Processing Record:Record Number 44; CityName:thinadhoo; QueryURL=http://api.openweathermap.org/data/2.5/weather?appid=1205305b6503b5009fc8c436728e1ea8&q=thinadhoo&units=metric
# Processing Record:Record Number 45; CityName:cape town; QueryURL=http://api.openweathermap.org/data/2.5/weather?appid=1205305b6503b5009fc8c436728e1ea8&q=cape town&units=metric
# Processing Record:Record Number 46; CityName:qaanaaq; QueryURL=http://api.openweathermap.org/data/2.5/weather?appid=1205305b6503b5009fc8c436728e1ea8&q=qaanaaq&units=metric
# Processing Record:Record Number 47; CityName:nyurba; QueryURL=http://api.openweathermap.org/data/2.5/weather?appid=1205305b6503b5009fc8c436728e1ea8&q=nyurba&units=metric
# Processing Record:Record Number 48; CityName:hermanus; QueryURL=http://api.openweathermap.org/data/2.5/weather?appid=1205305b6503b5009fc8c436728e1ea8&q=hermanus&units=metric
# Processing Record:Record Number 49; CityName:jaromerice nad rokytnou; QueryURL=http://api.openweathermap.org/data/2.5/weather?appid=1205305b6503b5009fc8c436728e1ea8&q=jaromerice nad rokytnou&units=metric
# Processing Record:Record Number 50; CityName:barentsburg; QueryURL=http://api.openweathermap.org/data/2.5/weather?appid=1205305b6503b5009fc8c436728e1ea8&q=barentsburg&units=metric
# NOT FOUND...Skipping Record Number 50; CityName:barentsburg
# Processing Record:Record Number 51; CityName:itarema; QueryURL=http://api.openweathermap.org/data/2.5/weather?appid=1205305b6503b5009fc8c436728e1ea8&q=itarema&units=metric
# Processing Record:Record Number 52; CityName:kuzino; QueryURL=http://api.openweathermap.org/data/2.5/weather?appid=1205305b6503b5009fc8c436728e1ea8&q=kuzino&units=metric
# Processing Record:Record Number 53; CityName:lebu; QueryURL=http://api.openweathermap.org/data/2.5/weather?appid=1205305b6503b5009fc8c436728e1ea8&q=lebu&units=metric
# Processing Record:Record Number 54; CityName:ambovombe; QueryURL=http://api.openweathermap.org/data/2.5/weather?appid=1205305b6503b5009fc8c436728e1ea8&q=ambovombe&units=metric
# Processing Record:Record Number 55; CityName:esperance; QueryURL=http://api.openweathermap.org/data/2.5/weather?appid=1205305b6503b5009fc8c436728e1ea8&q=esperance&units=metric
# Processing Record:Record Number 56; CityName:srednekolymsk; QueryURL=http://api.openweathermap.org/data/2.5/weather?appid=1205305b6503b5009fc8c436728e1ea8&q=srednekolymsk&units=metric
# Processing Record:Record Number 57; CityName:yulara; QueryURL=http://api.openweathermap.org/data/2.5/weather?appid=1205305b6503b5009fc8c436728e1ea8&q=yulara&units=metric
# Processing Record:Record Number 58; CityName:praia da vitoria; QueryURL=http://api.openweathermap.org/data/2.5/weather?appid=1205305b6503b5009fc8c436728e1ea8&q=praia da vitoria&units=metric
# Processing Record:Record Number 59; CityName:kisangani; QueryURL=http://api.openweathermap.org/data/2.5/weather?appid=1205305b6503b5009fc8c436728e1ea8&q=kisangani&units=metric
# Processing Record:Record Number 60; CityName:georgetown; QueryURL=http://api.openweathermap.org/data/2.5/weather?appid=1205305b6503b5009fc8c436728e1ea8&q=georgetown&units=metric
# Processing Record:Record Number 61; CityName:kirakira; QueryURL=http://api.openweathermap.org/data/2.5/weather?appid=1205305b6503b5009fc8c436728e1ea8&q=kirakira&units=metric
# Processing Record:Record Number 62; CityName:saldanha; QueryURL=http://api.openweathermap.org/data/2.5/weather?appid=1205305b6503b5009fc8c436728e1ea8&q=saldanha&units=metric
# Processing Record:Record Number 63; CityName:arraial do cabo; QueryURL=http://api.openweathermap.org/data/2.5/weather?appid=1205305b6503b5009fc8c436728e1ea8&q=arraial do cabo&units=metric
# Processing Record:Record Number 64; CityName:samusu; QueryURL=http://api.openweathermap.org/data/2.5/weather?appid=1205305b6503b5009fc8c436728e1ea8&q=samusu&units=metric
# NOT FOUND...Skipping Record Number 64; CityName:samusu
# Processing Record:Record Number 65; CityName:richards bay; QueryURL=http://api.openweathermap.org/data/2.5/weather?appid=1205305b6503b5009fc8c436728e1ea8&q=richards bay&units=metric
# Processing Record:Record Number 66; CityName:bara; QueryURL=http://api.openweathermap.org/data/2.5/weather?appid=1205305b6503b5009fc8c436728e1ea8&q=bara&units=metric
# Processing Record:Record Number 67; CityName:tiznit; QueryURL=http://api.openweathermap.org/data/2.5/weather?appid=1205305b6503b5009fc8c436728e1ea8&q=tiznit&units=metric
# Processing Record:Record Number 68; CityName:clyde river; QueryURL=http://api.openweathermap.org/data/2.5/weather?appid=1205305b6503b5009fc8c436728e1ea8&q=clyde river&units=metric
# Processing Record:Record Number 69; CityName:codrington; QueryURL=http://api.openweathermap.org/data/2.5/weather?appid=1205305b6503b5009fc8c436728e1ea8&q=codrington&units=metric
# Processing Record:Record Number 70; CityName:mar del plata; QueryURL=http://api.openweathermap.org/data/2.5/weather?appid=1205305b6503b5009fc8c436728e1ea8&q=mar del plata&units=metric
# Processing Record:Record Number 71; CityName:puerto ayora; QueryURL=http://api.openweathermap.org/data/2.5/weather?appid=1205305b6503b5009fc8c436728e1ea8&q=puerto ayora&units=metric
# Processing Record:Record Number 72; CityName:lavrentiya; QueryURL=http://api.openweathermap.org/data/2.5/weather?appid=1205305b6503b5009fc8c436728e1ea8&q=lavrentiya&units=metric
# Processing Record:Record Number 73; CityName:port elizabeth; QueryURL=http://api.openweathermap.org/data/2.5/weather?appid=1205305b6503b5009fc8c436728e1ea8&q=port elizabeth&units=metric
# Processing Record:Record Number 74; CityName:hamilton; QueryURL=http://api.openweathermap.org/data/2.5/weather?appid=1205305b6503b5009fc8c436728e1ea8&q=hamilton&units=metric
# Processing Record:Record Number 75; CityName:khatanga; QueryURL=http://api.openweathermap.org/data/2.5/weather?appid=1205305b6503b5009fc8c436728e1ea8&q=khatanga&units=metric
# Processing Record:Record Number 76; CityName:ushuaia; QueryURL=http://api.openweathermap.org/data/2.5/weather?appid=1205305b6503b5009fc8c436728e1ea8&q=ushuaia&units=metric
# Processing Record:Record Number 77; CityName:coquimbo; QueryURL=http://api.openweathermap.org/data/2.5/weather?appid=1205305b6503b5009fc8c436728e1ea8&q=coquimbo&units=metric
# Processing Record:Record Number 78; CityName:castro; QueryURL=http://api.openweathermap.org/data/2.5/weather?appid=1205305b6503b5009fc8c436728e1ea8&q=castro&units=metric
# Processing Record:Record Number 79; CityName:east london; QueryURL=http://api.openweathermap.org/data/2.5/weather?appid=1205305b6503b5009fc8c436728e1ea8&q=east london&units=metric
# Processing Record:Record Number 80; CityName:san jose; QueryURL=http://api.openweathermap.org/data/2.5/weather?appid=1205305b6503b5009fc8c436728e1ea8&q=san jose&units=metric
# Processing Record:Record Number 81; CityName:trelew; QueryURL=http://api.openweathermap.org/data/2.5/weather?appid=1205305b6503b5009fc8c436728e1ea8&q=trelew&units=metric
# Processing Record:Record Number 82; CityName:touros; QueryURL=http://api.openweathermap.org/data/2.5/weather?appid=1205305b6503b5009fc8c436728e1ea8&q=touros&units=metric
# Processing Record:Record Number 83; CityName:cherskiy; QueryURL=http://api.openweathermap.org/data/2.5/weather?appid=1205305b6503b5009fc8c436728e1ea8&q=cherskiy&units=metric
# Processing Record:Record Number 84; CityName:tura; QueryURL=http://api.openweathermap.org/data/2.5/weather?appid=1205305b6503b5009fc8c436728e1ea8&q=tura&units=metric
# Processing Record:Record Number 85; CityName:lompoc; QueryURL=http://api.openweathermap.org/data/2.5/weather?appid=1205305b6503b5009fc8c436728e1ea8&q=lompoc&units=metric
# Processing Record:Record Number 86; CityName:atuona; QueryURL=http://api.openweathermap.org/data/2.5/weather?appid=1205305b6503b5009fc8c436728e1ea8&q=atuona&units=metric
# Processing Record:Record Number 87; CityName:provideniya; QueryURL=http://api.openweathermap.org/data/2.5/weather?appid=1205305b6503b5009fc8c436728e1ea8&q=provideniya&units=metric
# Processing Record:Record Number 88; CityName:barrow; QueryURL=http://api.openweathermap.org/data/2.5/weather?appid=1205305b6503b5009fc8c436728e1ea8&q=barrow&units=metric
# Processing Record:Record Number 89; CityName:waingapu; QueryURL=http://api.openweathermap.org/data/2.5/weather?appid=1205305b6503b5009fc8c436728e1ea8&q=waingapu&units=metric
# Processing Record:Record Number 90; CityName:chuy; QueryURL=http://api.openweathermap.org/data/2.5/weather?appid=1205305b6503b5009fc8c436728e1ea8&q=chuy&units=metric
# Processing Record:Record Number 91; CityName:okhotsk; QueryURL=http://api.openweathermap.org/data/2.5/weather?appid=1205305b6503b5009fc8c436728e1ea8&q=okhotsk&units=metric
# Processing Record:Record Number 92; CityName:agudos; QueryURL=http://api.openweathermap.org/data/2.5/weather?appid=1205305b6503b5009fc8c436728e1ea8&q=agudos&units=metric
# Processing Record:Record Number 93; CityName:ruatoria; QueryURL=http://api.openweathermap.org/data/2.5/weather?appid=1205305b6503b5009fc8c436728e1ea8&q=ruatoria&units=metric
# NOT FOUND...Skipping Record Number 93; CityName:ruatoria
# Processing Record:Record Number 94; CityName:tsihombe; QueryURL=http://api.openweathermap.org/data/2.5/weather?appid=1205305b6503b5009fc8c436728e1ea8&q=tsihombe&units=metric
# NOT FOUND...Skipping Record Number 94; CityName:tsihombe
# Processing Record:Record Number 95; CityName:tuktoyaktuk; QueryURL=http://api.openweathermap.org/data/2.5/weather?appid=1205305b6503b5009fc8c436728e1ea8&q=tuktoyaktuk&units=metric
# Processing Record:Record Number 96; CityName:champerico; QueryURL=http://api.openweathermap.org/data/2.5/weather?appid=1205305b6503b5009fc8c436728e1ea8&q=champerico&units=metric
# Processing Record:Record Number 97; CityName:avarua; QueryURL=http://api.openweathermap.org/data/2.5/weather?appid=1205305b6503b5009fc8c436728e1ea8&q=avarua&units=metric
# Processing Record:Record Number 98; CityName:bredasdorp; QueryURL=http://api.openweathermap.org/data/2.5/weather?appid=1205305b6503b5009fc8c436728e1ea8&q=bredasdorp&units=metric
# Processing Record:Record Number 99; CityName:ugento; QueryURL=http://api.openweathermap.org/data/2.5/weather?appid=1205305b6503b5009fc8c436728e1ea8&q=ugento&units=metric
# Processing Record:Record Number 100; CityName:tingi; QueryURL=http://api.openweathermap.org/data/2.5/weather?appid=1205305b6503b5009fc8c436728e1ea8&q=tingi&units=metric
# Processing Record:Record Number 101; CityName:klaksvik; QueryURL=http://api.openweathermap.org/data/2.5/weather?appid=1205305b6503b5009fc8c436728e1ea8&q=klaksvik&units=metric
# Processing Record:Record Number 102; CityName:thompson; QueryURL=http://api.openweathermap.org/data/2.5/weather?appid=1205305b6503b5009fc8c436728e1ea8&q=thompson&units=metric
# Processing Record:Record Number 103; CityName:olga; QueryURL=http://api.openweathermap.org/data/2.5/weather?appid=1205305b6503b5009fc8c436728e1ea8&q=olga&units=metric
# Processing Record:Record Number 104; CityName:nanortalik; QueryURL=http://api.openweathermap.org/data/2.5/weather?appid=1205305b6503b5009fc8c436728e1ea8&q=nanortalik&units=metric
# Processing Record:Record Number 105; CityName:ribeira grande; QueryURL=http://api.openweathermap.org/data/2.5/weather?appid=1205305b6503b5009fc8c436728e1ea8&q=ribeira grande&units=metric
# Processing Record:Record Number 106; CityName:taolanaro; QueryURL=http://api.openweathermap.org/data/2.5/weather?appid=1205305b6503b5009fc8c436728e1ea8&q=taolanaro&units=metric
# NOT FOUND...Skipping Record Number 106; CityName:taolanaro
# Processing Record:Record Number 107; CityName:arlit; QueryURL=http://api.openweathermap.org/data/2.5/weather?appid=1205305b6503b5009fc8c436728e1ea8&q=arlit&units=metric
# Processing Record:Record Number 108; CityName:yinchuan; QueryURL=http://api.openweathermap.org/data/2.5/weather?appid=1205305b6503b5009fc8c436728e1ea8&q=yinchuan&units=metric
# Processing Record:Record Number 109; CityName:fortuna; QueryURL=http://api.openweathermap.org/data/2.5/weather?appid=1205305b6503b5009fc8c436728e1ea8&q=fortuna&units=metric
# Processing Record:Record Number 110; CityName:luderitz; QueryURL=http://api.openweathermap.org/data/2.5/weather?appid=1205305b6503b5009fc8c436728e1ea8&q=luderitz&units=metric
# Processing Record:Record Number 111; CityName:colares; QueryURL=http://api.openweathermap.org/data/2.5/weather?appid=1205305b6503b5009fc8c436728e1ea8&q=colares&units=metric
# Processing Record:Record Number 112; CityName:portland; QueryURL=http://api.openweathermap.org/data/2.5/weather?appid=1205305b6503b5009fc8c436728e1ea8&q=portland&units=metric
# Processing Record:Record Number 113; CityName:linxia; QueryURL=http://api.openweathermap.org/data/2.5/weather?appid=1205305b6503b5009fc8c436728e1ea8&q=linxia&units=metric
# Processing Record:Record Number 114; CityName:esna; QueryURL=http://api.openweathermap.org/data/2.5/weather?appid=1205305b6503b5009fc8c436728e1ea8&q=esna&units=metric
# Processing Record:Record Number 115; CityName:iracoubo; QueryURL=http://api.openweathermap.org/data/2.5/weather?appid=1205305b6503b5009fc8c436728e1ea8&q=iracoubo&units=metric
# Processing Record:Record Number 116; CityName:coihaique; QueryURL=http://api.openweathermap.org/data/2.5/weather?appid=1205305b6503b5009fc8c436728e1ea8&q=coihaique&units=metric
# Processing Record:Record Number 117; CityName:antofagasta; QueryURL=http://api.openweathermap.org/data/2.5/weather?appid=1205305b6503b5009fc8c436728e1ea8&q=antofagasta&units=metric
# Processing Record:Record Number 118; CityName:osa; QueryURL=http://api.openweathermap.org/data/2.5/weather?appid=1205305b6503b5009fc8c436728e1ea8&q=osa&units=metric
# Processing Record:Record Number 119; CityName:moose factory; QueryURL=http://api.openweathermap.org/data/2.5/weather?appid=1205305b6503b5009fc8c436728e1ea8&q=moose factory&units=metric
# Processing Record:Record Number 120; CityName:palabuhanratu; QueryURL=http://api.openweathermap.org/data/2.5/weather?appid=1205305b6503b5009fc8c436728e1ea8&q=palabuhanratu&units=metric
# NOT FOUND...Skipping Record Number 120; CityName:palabuhanratu
# Processing Record:Record Number 121; CityName:watertown; QueryURL=http://api.openweathermap.org/data/2.5/weather?appid=1205305b6503b5009fc8c436728e1ea8&q=watertown&units=metric
# Processing Record:Record Number 122; CityName:talnakh; QueryURL=http://api.openweathermap.org/data/2.5/weather?appid=1205305b6503b5009fc8c436728e1ea8&q=talnakh&units=metric
# Processing Record:Record Number 123; CityName:birao; QueryURL=http://api.openweathermap.org/data/2.5/weather?appid=1205305b6503b5009fc8c436728e1ea8&q=birao&units=metric
# Processing Record:Record Number 124; CityName:mahebourg; QueryURL=http://api.openweathermap.org/data/2.5/weather?appid=1205305b6503b5009fc8c436728e1ea8&q=mahebourg&units=metric
# Processing Record:Record Number 125; CityName:kodiak; QueryURL=http://api.openweathermap.org/data/2.5/weather?appid=1205305b6503b5009fc8c436728e1ea8&q=kodiak&units=metric
# Processing Record:Record Number 126; CityName:lyuban; QueryURL=http://api.openweathermap.org/data/2.5/weather?appid=1205305b6503b5009fc8c436728e1ea8&q=lyuban&units=metric
# Processing Record:Record Number 127; CityName:aksarayskiy; QueryURL=http://api.openweathermap.org/data/2.5/weather?appid=1205305b6503b5009fc8c436728e1ea8&q=aksarayskiy&units=metric
# Processing Record:Record Number 128; CityName:nakonde; QueryURL=http://api.openweathermap.org/data/2.5/weather?appid=1205305b6503b5009fc8c436728e1ea8&q=nakonde&units=metric
# Processing Record:Record Number 129; CityName:ostrovnoy; QueryURL=http://api.openweathermap.org/data/2.5/weather?appid=1205305b6503b5009fc8c436728e1ea8&q=ostrovnoy&units=metric
# Processing Record:Record Number 130; CityName:villa maria; QueryURL=http://api.openweathermap.org/data/2.5/weather?appid=1205305b6503b5009fc8c436728e1ea8&q=villa maria&units=metric
# Processing Record:Record Number 131; CityName:karamea; QueryURL=http://api.openweathermap.org/data/2.5/weather?appid=1205305b6503b5009fc8c436728e1ea8&q=karamea&units=metric
# NOT FOUND...Skipping Record Number 131; CityName:karamea
# Processing Record:Record Number 132; CityName:starodub; QueryURL=http://api.openweathermap.org/data/2.5/weather?appid=1205305b6503b5009fc8c436728e1ea8&q=starodub&units=metric
# Processing Record:Record Number 133; CityName:narsaq; QueryURL=http://api.openweathermap.org/data/2.5/weather?appid=1205305b6503b5009fc8c436728e1ea8&q=narsaq&units=metric
# Processing Record:Record Number 134; CityName:yellowknife; QueryURL=http://api.openweathermap.org/data/2.5/weather?appid=1205305b6503b5009fc8c436728e1ea8&q=yellowknife&units=metric
# Processing Record:Record Number 135; CityName:vostok; QueryURL=http://api.openweathermap.org/data/2.5/weather?appid=1205305b6503b5009fc8c436728e1ea8&q=vostok&units=metric
# Processing Record:Record Number 136; CityName:borama; QueryURL=http://api.openweathermap.org/data/2.5/weather?appid=1205305b6503b5009fc8c436728e1ea8&q=borama&units=metric
# NOT FOUND...Skipping Record Number 136; CityName:borama
# Processing Record:Record Number 137; CityName:crixas; QueryURL=http://api.openweathermap.org/data/2.5/weather?appid=1205305b6503b5009fc8c436728e1ea8&q=crixas&units=metric
# Processing Record:Record Number 138; CityName:lerwick; QueryURL=http://api.openweathermap.org/data/2.5/weather?appid=1205305b6503b5009fc8c436728e1ea8&q=lerwick&units=metric
# Processing Record:Record Number 139; CityName:albany; QueryURL=http://api.openweathermap.org/data/2.5/weather?appid=1205305b6503b5009fc8c436728e1ea8&q=albany&units=metric
# Processing Record:Record Number 140; CityName:carnarvon; QueryURL=http://api.openweathermap.org/data/2.5/weather?appid=1205305b6503b5009fc8c436728e1ea8&q=carnarvon&units=metric
# Processing Record:Record Number 141; CityName:mount gambier; QueryURL=http://api.openweathermap.org/data/2.5/weather?appid=1205305b6503b5009fc8c436728e1ea8&q=mount gambier&units=metric
# Processing Record:Record Number 142; CityName:najran; QueryURL=http://api.openweathermap.org/data/2.5/weather?appid=1205305b6503b5009fc8c436728e1ea8&q=najran&units=metric
# Processing Record:Record Number 143; CityName:san quintin; QueryURL=http://api.openweathermap.org/data/2.5/weather?appid=1205305b6503b5009fc8c436728e1ea8&q=san quintin&units=metric
# Processing Record:Record Number 144; CityName:bethel; QueryURL=http://api.openweathermap.org/data/2.5/weather?appid=1205305b6503b5009fc8c436728e1ea8&q=bethel&units=metric
# Processing Record:Record Number 145; CityName:north bend; QueryURL=http://api.openweathermap.org/data/2.5/weather?appid=1205305b6503b5009fc8c436728e1ea8&q=north bend&units=metric
# Processing Record:Record Number 146; CityName:mys shmidta; QueryURL=http://api.openweathermap.org/data/2.5/weather?appid=1205305b6503b5009fc8c436728e1ea8&q=mys shmidta&units=metric
# NOT FOUND...Skipping Record Number 146; CityName:mys shmidta
# Processing Record:Record Number 147; CityName:tarakan; QueryURL=http://api.openweathermap.org/data/2.5/weather?appid=1205305b6503b5009fc8c436728e1ea8&q=tarakan&units=metric
# Processing Record:Record Number 148; CityName:dingle; QueryURL=http://api.openweathermap.org/data/2.5/weather?appid=1205305b6503b5009fc8c436728e1ea8&q=dingle&units=metric
# Processing Record:Record Number 149; CityName:buin; QueryURL=http://api.openweathermap.org/data/2.5/weather?appid=1205305b6503b5009fc8c436728e1ea8&q=buin&units=metric
# Processing Record:Record Number 150; CityName:havre-saint-pierre; QueryURL=http://api.openweathermap.org/data/2.5/weather?appid=1205305b6503b5009fc8c436728e1ea8&q=havre-saint-pierre&units=metric
# Processing Record:Record Number 151; CityName:pisco; QueryURL=http://api.openweathermap.org/data/2.5/weather?appid=1205305b6503b5009fc8c436728e1ea8&q=pisco&units=metric
# Processing Record:Record Number 152; CityName:iquitos; QueryURL=http://api.openweathermap.org/data/2.5/weather?appid=1205305b6503b5009fc8c436728e1ea8&q=iquitos&units=metric
# Processing Record:Record Number 153; CityName:jalu; QueryURL=http://api.openweathermap.org/data/2.5/weather?appid=1205305b6503b5009fc8c436728e1ea8&q=jalu&units=metric
# Processing Record:Record Number 154; CityName:valparaiso; QueryURL=http://api.openweathermap.org/data/2.5/weather?appid=1205305b6503b5009fc8c436728e1ea8&q=valparaiso&units=metric
# Processing Record:Record Number 155; CityName:cabedelo; QueryURL=http://api.openweathermap.org/data/2.5/weather?appid=1205305b6503b5009fc8c436728e1ea8&q=cabedelo&units=metric
# Processing Record:Record Number 156; CityName:sao joao de pirabas; QueryURL=http://api.openweathermap.org/data/2.5/weather?appid=1205305b6503b5009fc8c436728e1ea8&q=sao joao de pirabas&units=metric
# Processing Record:Record Number 157; CityName:rundu; QueryURL=http://api.openweathermap.org/data/2.5/weather?appid=1205305b6503b5009fc8c436728e1ea8&q=rundu&units=metric
# Processing Record:Record Number 158; CityName:san rafael; QueryURL=http://api.openweathermap.org/data/2.5/weather?appid=1205305b6503b5009fc8c436728e1ea8&q=san rafael&units=metric
# Processing Record:Record Number 159; CityName:nouadhibou; QueryURL=http://api.openweathermap.org/data/2.5/weather?appid=1205305b6503b5009fc8c436728e1ea8&q=nouadhibou&units=metric
# Processing Record:Record Number 160; CityName:meulaboh; QueryURL=http://api.openweathermap.org/data/2.5/weather?appid=1205305b6503b5009fc8c436728e1ea8&q=meulaboh&units=metric
# Processing Record:Record Number 161; CityName:teya; QueryURL=http://api.openweathermap.org/data/2.5/weather?appid=1205305b6503b5009fc8c436728e1ea8&q=teya&units=metric
# Processing Record:Record Number 162; CityName:hayvoron; QueryURL=http://api.openweathermap.org/data/2.5/weather?appid=1205305b6503b5009fc8c436728e1ea8&q=hayvoron&units=metric
# Processing Record:Record Number 163; CityName:mehamn; QueryURL=http://api.openweathermap.org/data/2.5/weather?appid=1205305b6503b5009fc8c436728e1ea8&q=mehamn&units=metric
# Processing Record:Record Number 164; CityName:lingyuan; QueryURL=http://api.openweathermap.org/data/2.5/weather?appid=1205305b6503b5009fc8c436728e1ea8&q=lingyuan&units=metric
# Processing Record:Record Number 165; CityName:grand river south east; QueryURL=http://api.openweathermap.org/data/2.5/weather?appid=1205305b6503b5009fc8c436728e1ea8&q=grand river south east&units=metric
# NOT FOUND...Skipping Record Number 165; CityName:grand river south east
# Processing Record:Record Number 166; CityName:riyadh; QueryURL=http://api.openweathermap.org/data/2.5/weather?appid=1205305b6503b5009fc8c436728e1ea8&q=riyadh&units=metric
# Processing Record:Record Number 167; CityName:carros; QueryURL=http://api.openweathermap.org/data/2.5/weather?appid=1205305b6503b5009fc8c436728e1ea8&q=carros&units=metric
# Processing Record:Record Number 168; CityName:saint george; QueryURL=http://api.openweathermap.org/data/2.5/weather?appid=1205305b6503b5009fc8c436728e1ea8&q=saint george&units=metric
# Processing Record:Record Number 169; CityName:nikolskoye; QueryURL=http://api.openweathermap.org/data/2.5/weather?appid=1205305b6503b5009fc8c436728e1ea8&q=nikolskoye&units=metric
# Processing Record:Record Number 170; CityName:ugoofaaru; QueryURL=http://api.openweathermap.org/data/2.5/weather?appid=1205305b6503b5009fc8c436728e1ea8&q=ugoofaaru&units=metric
# Processing Record:Record Number 171; CityName:marzuq; QueryURL=http://api.openweathermap.org/data/2.5/weather?appid=1205305b6503b5009fc8c436728e1ea8&q=marzuq&units=metric
# Processing Record:Record Number 172; CityName:polyarnyy; QueryURL=http://api.openweathermap.org/data/2.5/weather?appid=1205305b6503b5009fc8c436728e1ea8&q=polyarnyy&units=metric
# Processing Record:Record Number 173; CityName:neuquen; QueryURL=http://api.openweathermap.org/data/2.5/weather?appid=1205305b6503b5009fc8c436728e1ea8&q=neuquen&units=metric
# Processing Record:Record Number 174; CityName:azimur; QueryURL=http://api.openweathermap.org/data/2.5/weather?appid=1205305b6503b5009fc8c436728e1ea8&q=azimur&units=metric
# NOT FOUND...Skipping Record Number 174; CityName:azimur
# Processing Record:Record Number 175; CityName:san patricio; QueryURL=http://api.openweathermap.org/data/2.5/weather?appid=1205305b6503b5009fc8c436728e1ea8&q=san patricio&units=metric
# Processing Record:Record Number 176; CityName:hilo; QueryURL=http://api.openweathermap.org/data/2.5/weather?appid=1205305b6503b5009fc8c436728e1ea8&q=hilo&units=metric
# Processing Record:Record Number 177; CityName:shimoda; QueryURL=http://api.openweathermap.org/data/2.5/weather?appid=1205305b6503b5009fc8c436728e1ea8&q=shimoda&units=metric
# Processing Record:Record Number 178; CityName:karasjok; QueryURL=http://api.openweathermap.org/data/2.5/weather?appid=1205305b6503b5009fc8c436728e1ea8&q=karasjok&units=metric
# Processing Record:Record Number 179; CityName:beringovskiy; QueryURL=http://api.openweathermap.org/data/2.5/weather?appid=1205305b6503b5009fc8c436728e1ea8&q=beringovskiy&units=metric
# Processing Record:Record Number 180; CityName:novikovo; QueryURL=http://api.openweathermap.org/data/2.5/weather?appid=1205305b6503b5009fc8c436728e1ea8&q=novikovo&units=metric
# Processing Record:Record Number 181; CityName:oriximina; QueryURL=http://api.openweathermap.org/data/2.5/weather?appid=1205305b6503b5009fc8c436728e1ea8&q=oriximina&units=metric
# Processing Record:Record Number 182; CityName:mizdah; QueryURL=http://api.openweathermap.org/data/2.5/weather?appid=1205305b6503b5009fc8c436728e1ea8&q=mizdah&units=metric
# Processing Record:Record Number 183; CityName:guararapes; QueryURL=http://api.openweathermap.org/data/2.5/weather?appid=1205305b6503b5009fc8c436728e1ea8&q=guararapes&units=metric
# Processing Record:Record Number 184; CityName:vila franca do campo; QueryURL=http://api.openweathermap.org/data/2.5/weather?appid=1205305b6503b5009fc8c436728e1ea8&q=vila franca do campo&units=metric
# Processing Record:Record Number 185; CityName:sitka; QueryURL=http://api.openweathermap.org/data/2.5/weather?appid=1205305b6503b5009fc8c436728e1ea8&q=sitka&units=metric
# Processing Record:Record Number 186; CityName:yenagoa; QueryURL=http://api.openweathermap.org/data/2.5/weather?appid=1205305b6503b5009fc8c436728e1ea8&q=yenagoa&units=metric
# Processing Record:Record Number 187; CityName:amderma; QueryURL=http://api.openweathermap.org/data/2.5/weather?appid=1205305b6503b5009fc8c436728e1ea8&q=amderma&units=metric
# NOT FOUND...Skipping Record Number 187; CityName:amderma
# Processing Record:Record Number 188; CityName:constitucion; QueryURL=http://api.openweathermap.org/data/2.5/weather?appid=1205305b6503b5009fc8c436728e1ea8&q=constitucion&units=metric
# Processing Record:Record Number 189; CityName:bodden town; QueryURL=http://api.openweathermap.org/data/2.5/weather?appid=1205305b6503b5009fc8c436728e1ea8&q=bodden town&units=metric
# Processing Record:Record Number 190; CityName:thayetmyo; QueryURL=http://api.openweathermap.org/data/2.5/weather?appid=1205305b6503b5009fc8c436728e1ea8&q=thayetmyo&units=metric
# Processing Record:Record Number 191; CityName:saskylakh; QueryURL=http://api.openweathermap.org/data/2.5/weather?appid=1205305b6503b5009fc8c436728e1ea8&q=saskylakh&units=metric
# Processing Record:Record Number 192; CityName:high level; QueryURL=http://api.openweathermap.org/data/2.5/weather?appid=1205305b6503b5009fc8c436728e1ea8&q=high level&units=metric
# Processing Record:Record Number 193; CityName:gerede; QueryURL=http://api.openweathermap.org/data/2.5/weather?appid=1205305b6503b5009fc8c436728e1ea8&q=gerede&units=metric
# Processing Record:Record Number 194; CityName:ballina; QueryURL=http://api.openweathermap.org/data/2.5/weather?appid=1205305b6503b5009fc8c436728e1ea8&q=ballina&units=metric
# Processing Record:Record Number 195; CityName:poum; QueryURL=http://api.openweathermap.org/data/2.5/weather?appid=1205305b6503b5009fc8c436728e1ea8&q=poum&units=metric
# Processing Record:Record Number 196; CityName:ponta do sol; QueryURL=http://api.openweathermap.org/data/2.5/weather?appid=1205305b6503b5009fc8c436728e1ea8&q=ponta do sol&units=metric
# Processing Record:Record Number 197; CityName:songea; QueryURL=http://api.openweathermap.org/data/2.5/weather?appid=1205305b6503b5009fc8c436728e1ea8&q=songea&units=metric
# Processing Record:Record Number 198; CityName:yabrud; QueryURL=http://api.openweathermap.org/data/2.5/weather?appid=1205305b6503b5009fc8c436728e1ea8&q=yabrud&units=metric
# Processing Record:Record Number 199; CityName:bucerias; QueryURL=http://api.openweathermap.org/data/2.5/weather?appid=1205305b6503b5009fc8c436728e1ea8&q=bucerias&units=metric
# Processing Record:Record Number 200; CityName:rybnoye; QueryURL=http://api.openweathermap.org/data/2.5/weather?appid=1205305b6503b5009fc8c436728e1ea8&q=rybnoye&units=metric
# Processing Record:Record Number 201; CityName:laguna; QueryURL=http://api.openweathermap.org/data/2.5/weather?appid=1205305b6503b5009fc8c436728e1ea8&q=laguna&units=metric
# Processing Record:Record Number 202; CityName:severnoye; QueryURL=http://api.openweathermap.org/data/2.5/weather?appid=1205305b6503b5009fc8c436728e1ea8&q=severnoye&units=metric
# Processing Record:Record Number 203; CityName:nemuro; QueryURL=http://api.openweathermap.org/data/2.5/weather?appid=1205305b6503b5009fc8c436728e1ea8&q=nemuro&units=metric
# Processing Record:Record Number 204; CityName:massakory; QueryURL=http://api.openweathermap.org/data/2.5/weather?appid=1205305b6503b5009fc8c436728e1ea8&q=massakory&units=metric
# Processing Record:Record Number 205; CityName:kapaa; QueryURL=http://api.openweathermap.org/data/2.5/weather?appid=1205305b6503b5009fc8c436728e1ea8&q=kapaa&units=metric
# Processing Record:Record Number 206; CityName:rabaul; QueryURL=http://api.openweathermap.org/data/2.5/weather?appid=1205305b6503b5009fc8c436728e1ea8&q=rabaul&units=metric
# Processing Record:Record Number 207; CityName:mastic beach; QueryURL=http://api.openweathermap.org/data/2.5/weather?appid=1205305b6503b5009fc8c436728e1ea8&q=mastic beach&units=metric
# Processing Record:Record Number 208; CityName:sola; QueryURL=http://api.openweathermap.org/data/2.5/weather?appid=1205305b6503b5009fc8c436728e1ea8&q=sola&units=metric
# Processing Record:Record Number 209; CityName:hithadhoo; QueryURL=http://api.openweathermap.org/data/2.5/weather?appid=1205305b6503b5009fc8c436728e1ea8&q=hithadhoo&units=metric
# Processing Record:Record Number 210; CityName:kamenskoye; QueryURL=http://api.openweathermap.org/data/2.5/weather?appid=1205305b6503b5009fc8c436728e1ea8&q=kamenskoye&units=metric
# NOT FOUND...Skipping Record Number 210; CityName:kamenskoye
# Processing Record:Record Number 211; CityName:itoman; QueryURL=http://api.openweathermap.org/data/2.5/weather?appid=1205305b6503b5009fc8c436728e1ea8&q=itoman&units=metric
# Processing Record:Record Number 212; CityName:kahului; QueryURL=http://api.openweathermap.org/data/2.5/weather?appid=1205305b6503b5009fc8c436728e1ea8&q=kahului&units=metric
# Processing Record:Record Number 213; CityName:kharp; QueryURL=http://api.openweathermap.org/data/2.5/weather?appid=1205305b6503b5009fc8c436728e1ea8&q=kharp&units=metric
# Processing Record:Record Number 214; CityName:bengkulu; QueryURL=http://api.openweathermap.org/data/2.5/weather?appid=1205305b6503b5009fc8c436728e1ea8&q=bengkulu&units=metric
# NOT FOUND...Skipping Record Number 214; CityName:bengkulu
# Processing Record:Record Number 215; CityName:zhigansk; QueryURL=http://api.openweathermap.org/data/2.5/weather?appid=1205305b6503b5009fc8c436728e1ea8&q=zhigansk&units=metric
# Processing Record:Record Number 216; CityName:maudaha; QueryURL=http://api.openweathermap.org/data/2.5/weather?appid=1205305b6503b5009fc8c436728e1ea8&q=maudaha&units=metric
# Processing Record:Record Number 217; CityName:kharhial; QueryURL=http://api.openweathermap.org/data/2.5/weather?appid=1205305b6503b5009fc8c436728e1ea8&q=kharhial&units=metric
# Processing Record:Record Number 218; CityName:mahon; QueryURL=http://api.openweathermap.org/data/2.5/weather?appid=1205305b6503b5009fc8c436728e1ea8&q=mahon&units=metric
# Processing Record:Record Number 219; CityName:new norfolk; QueryURL=http://api.openweathermap.org/data/2.5/weather?appid=1205305b6503b5009fc8c436728e1ea8&q=new norfolk&units=metric
# Processing Record:Record Number 220; CityName:zhanaozen; QueryURL=http://api.openweathermap.org/data/2.5/weather?appid=1205305b6503b5009fc8c436728e1ea8&q=zhanaozen&units=metric
# Processing Record:Record Number 221; CityName:mundargi; QueryURL=http://api.openweathermap.org/data/2.5/weather?appid=1205305b6503b5009fc8c436728e1ea8&q=mundargi&units=metric
# Processing Record:Record Number 222; CityName:ketchikan; QueryURL=http://api.openweathermap.org/data/2.5/weather?appid=1205305b6503b5009fc8c436728e1ea8&q=ketchikan&units=metric
# Processing Record:Record Number 223; CityName:airai; QueryURL=http://api.openweathermap.org/data/2.5/weather?appid=1205305b6503b5009fc8c436728e1ea8&q=airai&units=metric
# Processing Record:Record Number 224; CityName:darhan; QueryURL=http://api.openweathermap.org/data/2.5/weather?appid=1205305b6503b5009fc8c436728e1ea8&q=darhan&units=metric
# Processing Record:Record Number 225; CityName:cabo san lucas; QueryURL=http://api.openweathermap.org/data/2.5/weather?appid=1205305b6503b5009fc8c436728e1ea8&q=cabo san lucas&units=metric
# Processing Record:Record Number 226; CityName:namibe; QueryURL=http://api.openweathermap.org/data/2.5/weather?appid=1205305b6503b5009fc8c436728e1ea8&q=namibe&units=metric
# Processing Record:Record Number 227; CityName:nabire; QueryURL=http://api.openweathermap.org/data/2.5/weather?appid=1205305b6503b5009fc8c436728e1ea8&q=nabire&units=metric
# Processing Record:Record Number 228; CityName:the valley; QueryURL=http://api.openweathermap.org/data/2.5/weather?appid=1205305b6503b5009fc8c436728e1ea8&q=the valley&units=metric
# Processing Record:Record Number 229; CityName:port macquarie; QueryURL=http://api.openweathermap.org/data/2.5/weather?appid=1205305b6503b5009fc8c436728e1ea8&q=port macquarie&units=metric
# Processing Record:Record Number 230; CityName:alofi; QueryURL=http://api.openweathermap.org/data/2.5/weather?appid=1205305b6503b5009fc8c436728e1ea8&q=alofi&units=metric
# Processing Record:Record Number 231; CityName:high rock; QueryURL=http://api.openweathermap.org/data/2.5/weather?appid=1205305b6503b5009fc8c436728e1ea8&q=high rock&units=metric
# Processing Record:Record Number 232; CityName:vardo; QueryURL=http://api.openweathermap.org/data/2.5/weather?appid=1205305b6503b5009fc8c436728e1ea8&q=vardo&units=metric
# Processing Record:Record Number 233; CityName:kindu; QueryURL=http://api.openweathermap.org/data/2.5/weather?appid=1205305b6503b5009fc8c436728e1ea8&q=kindu&units=metric
# Processing Record:Record Number 234; CityName:port-gentil; QueryURL=http://api.openweathermap.org/data/2.5/weather?appid=1205305b6503b5009fc8c436728e1ea8&q=port-gentil&units=metric
# Processing Record:Record Number 235; CityName:oussouye; QueryURL=http://api.openweathermap.org/data/2.5/weather?appid=1205305b6503b5009fc8c436728e1ea8&q=oussouye&units=metric
# Processing Record:Record Number 236; CityName:freeport; QueryURL=http://api.openweathermap.org/data/2.5/weather?appid=1205305b6503b5009fc8c436728e1ea8&q=freeport&units=metric
# Processing Record:Record Number 237; CityName:mbengwi; QueryURL=http://api.openweathermap.org/data/2.5/weather?appid=1205305b6503b5009fc8c436728e1ea8&q=mbengwi&units=metric
# Processing Record:Record Number 238; CityName:egvekinot; QueryURL=http://api.openweathermap.org/data/2.5/weather?appid=1205305b6503b5009fc8c436728e1ea8&q=egvekinot&units=metric
# Processing Record:Record Number 239; CityName:maues; QueryURL=http://api.openweathermap.org/data/2.5/weather?appid=1205305b6503b5009fc8c436728e1ea8&q=maues&units=metric
# Processing Record:Record Number 240; CityName:madruga; QueryURL=http://api.openweathermap.org/data/2.5/weather?appid=1205305b6503b5009fc8c436728e1ea8&q=madruga&units=metric
# Processing Record:Record Number 241; CityName:yaan; QueryURL=http://api.openweathermap.org/data/2.5/weather?appid=1205305b6503b5009fc8c436728e1ea8&q=yaan&units=metric
# Processing Record:Record Number 242; CityName:varhaug; QueryURL=http://api.openweathermap.org/data/2.5/weather?appid=1205305b6503b5009fc8c436728e1ea8&q=varhaug&units=metric
# Processing Record:Record Number 243; CityName:soyo; QueryURL=http://api.openweathermap.org/data/2.5/weather?appid=1205305b6503b5009fc8c436728e1ea8&q=soyo&units=metric
# Processing Record:Record Number 244; CityName:san cristobal; QueryURL=http://api.openweathermap.org/data/2.5/weather?appid=1205305b6503b5009fc8c436728e1ea8&q=san cristobal&units=metric
# Processing Record:Record Number 245; CityName:ketou; QueryURL=http://api.openweathermap.org/data/2.5/weather?appid=1205305b6503b5009fc8c436728e1ea8&q=ketou&units=metric
# Processing Record:Record Number 246; CityName:tapaua; QueryURL=http://api.openweathermap.org/data/2.5/weather?appid=1205305b6503b5009fc8c436728e1ea8&q=tapaua&units=metric
# NOT FOUND...Skipping Record Number 246; CityName:tapaua
# Processing Record:Record Number 247; CityName:grand gaube; QueryURL=http://api.openweathermap.org/data/2.5/weather?appid=1205305b6503b5009fc8c436728e1ea8&q=grand gaube&units=metric
# Processing Record:Record Number 248; CityName:outlook; QueryURL=http://api.openweathermap.org/data/2.5/weather?appid=1205305b6503b5009fc8c436728e1ea8&q=outlook&units=metric
# Processing Record:Record Number 249; CityName:pietarsaari; QueryURL=http://api.openweathermap.org/data/2.5/weather?appid=1205305b6503b5009fc8c436728e1ea8&q=pietarsaari&units=metric
# NOT FOUND...Skipping Record Number 249; CityName:pietarsaari
# Processing Record:Record Number 250; CityName:sarakhs; QueryURL=http://api.openweathermap.org/data/2.5/weather?appid=1205305b6503b5009fc8c436728e1ea8&q=sarakhs&units=metric
# Processing Record:Record Number 251; CityName:malanje; QueryURL=http://api.openweathermap.org/data/2.5/weather?appid=1205305b6503b5009fc8c436728e1ea8&q=malanje&units=metric
# Processing Record:Record Number 252; CityName:neftcala; QueryURL=http://api.openweathermap.org/data/2.5/weather?appid=1205305b6503b5009fc8c436728e1ea8&q=neftcala&units=metric
# Processing Record:Record Number 253; CityName:karratha; QueryURL=http://api.openweathermap.org/data/2.5/weather?appid=1205305b6503b5009fc8c436728e1ea8&q=karratha&units=metric
# Processing Record:Record Number 254; CityName:suez; QueryURL=http://api.openweathermap.org/data/2.5/weather?appid=1205305b6503b5009fc8c436728e1ea8&q=suez&units=metric
# Processing Record:Record Number 255; CityName:butaritari; QueryURL=http://api.openweathermap.org/data/2.5/weather?appid=1205305b6503b5009fc8c436728e1ea8&q=butaritari&units=metric
# Processing Record:Record Number 256; CityName:harrisonburg; QueryURL=http://api.openweathermap.org/data/2.5/weather?appid=1205305b6503b5009fc8c436728e1ea8&q=harrisonburg&units=metric
# Processing Record:Record Number 257; CityName:yima; QueryURL=http://api.openweathermap.org/data/2.5/weather?appid=1205305b6503b5009fc8c436728e1ea8&q=yima&units=metric
# Processing Record:Record Number 258; CityName:santa pola; QueryURL=http://api.openweathermap.org/data/2.5/weather?appid=1205305b6503b5009fc8c436728e1ea8&q=santa pola&units=metric
# Processing Record:Record Number 259; CityName:viseu; QueryURL=http://api.openweathermap.org/data/2.5/weather?appid=1205305b6503b5009fc8c436728e1ea8&q=viseu&units=metric
# Processing Record:Record Number 260; CityName:giengen; QueryURL=http://api.openweathermap.org/data/2.5/weather?appid=1205305b6503b5009fc8c436728e1ea8&q=giengen&units=metric
# NOT FOUND...Skipping Record Number 260; CityName:giengen
# Processing Record:Record Number 261; CityName:cap malheureux; QueryURL=http://api.openweathermap.org/data/2.5/weather?appid=1205305b6503b5009fc8c436728e1ea8&q=cap malheureux&units=metric
# Processing Record:Record Number 262; CityName:faanui; QueryURL=http://api.openweathermap.org/data/2.5/weather?appid=1205305b6503b5009fc8c436728e1ea8&q=faanui&units=metric
# Processing Record:Record Number 263; CityName:we; QueryURL=http://api.openweathermap.org/data/2.5/weather?appid=1205305b6503b5009fc8c436728e1ea8&q=we&units=metric
# NOT FOUND...Skipping Record Number 263; CityName:we
# Processing Record:Record Number 264; CityName:torbay; QueryURL=http://api.openweathermap.org/data/2.5/weather?appid=1205305b6503b5009fc8c436728e1ea8&q=torbay&units=metric
# Processing Record:Record Number 265; CityName:quelimane; QueryURL=http://api.openweathermap.org/data/2.5/weather?appid=1205305b6503b5009fc8c436728e1ea8&q=quelimane&units=metric
# Processing Record:Record Number 266; CityName:deder; QueryURL=http://api.openweathermap.org/data/2.5/weather?appid=1205305b6503b5009fc8c436728e1ea8&q=deder&units=metric
# Processing Record:Record Number 267; CityName:rincon; QueryURL=http://api.openweathermap.org/data/2.5/weather?appid=1205305b6503b5009fc8c436728e1ea8&q=rincon&units=metric
# ...
# Processing Record:Record Number 514; CityName:porto novo; QueryURL=http://api.openweathermap.org/data/2.5/weather?appid=1205305b6503b5009fc8c436728e1ea8&q=porto novo&units=metric
# Processing Record:Record Number 515; CityName:guanhaes; QueryURL=http://api.openweathermap.org/data/2.5/weather?appid=1205305b6503b5009fc8c436728e1ea8&q=guanhaes&units=metric
# Processing Record:Record Number 516; CityName:aras; QueryURL=http://api.openweathermap.org/data/2.5/weather?appid=1205305b6503b5009fc8c436728e1ea8&q=aras&units=metric
# Processing Record:Record Number 517; CityName:guerrero; QueryURL=http://api.openweathermap.org/data/2.5/weather?appid=1205305b6503b5009fc8c436728e1ea8&q=guerrero&units=metric
# Processing Record:Record Number 518; CityName:sambava; QueryURL=http://api.openweathermap.org/data/2.5/weather?appid=1205305b6503b5009fc8c436728e1ea8&q=sambava&units=metric
# Processing Record:Record Number 519; CityName:elizabeth city; QueryURL=http://api.openweathermap.org/data/2.5/weather?appid=1205305b6503b5009fc8c436728e1ea8&q=elizabeth city&units=metric
# Processing Record:Record Number 520; CityName:muswellbrook; QueryURL=http://api.openweathermap.org/data/2.5/weather?appid=1205305b6503b5009fc8c436728e1ea8&q=muswellbrook&units=metric
# Processing Record:Record Number 521; CityName:katima mulilo; QueryURL=http://api.openweathermap.org/data/2.5/weather?appid=1205305b6503b5009fc8c436728e1ea8&q=katima mulilo&units=metric
# Processing Record:Record Number 522; CityName:ceyhan; QueryURL=http://api.openweathermap.org/data/2.5/weather?appid=1205305b6503b5009fc8c436728e1ea8&q=ceyhan&units=metric
# Processing Record:Record Number 523; CityName:ejido; QueryURL=http://api.openweathermap.org/data/2.5/weather?appid=1205305b6503b5009fc8c436728e1ea8&q=ejido&units=metric
# Processing Record:Record Number 524; CityName:kavieng; QueryURL=http://api.openweathermap.org/data/2.5/weather?appid=1205305b6503b5009fc8c436728e1ea8&q=kavieng&units=metric
# Processing Record:Record Number 525; CityName:na klang; QueryURL=http://api.openweathermap.org/data/2.5/weather?appid=1205305b6503b5009fc8c436728e1ea8&q=na klang&units=metric
# Processing Record:Record Number 526; CityName:huarmey; QueryURL=http://api.openweathermap.org/data/2.5/weather?appid=1205305b6503b5009fc8c436728e1ea8&q=huarmey&units=metric
# Processing Record:Record Number 527; CityName:takaka; QueryURL=http://api.openweathermap.org/data/2.5/weather?appid=1205305b6503b5009fc8c436728e1ea8&q=takaka&units=metric
# Processing Record:Record Number 528; CityName:tecoanapa; QueryURL=http://api.openweathermap.org/data/2.5/weather?appid=1205305b6503b5009fc8c436728e1ea8&q=tecoanapa&units=metric
# Processing Record:Record Number 529; CityName:velizh; QueryURL=http://api.openweathermap.org/data/2.5/weather?appid=1205305b6503b5009fc8c436728e1ea8&q=velizh&units=metric
# Processing Record:Record Number 530; CityName:pingxiang; QueryURL=http://api.openweathermap.org/data/2.5/weather?appid=1205305b6503b5009fc8c436728e1ea8&q=pingxiang&units=metric
# Processing Record:Record Number 531; CityName:omboue; QueryURL=http://api.openweathermap.org/data/2.5/weather?appid=1205305b6503b5009fc8c436728e1ea8&q=omboue&units=metric
# Processing Record:Record Number 532; CityName:copiapo; QueryURL=http://api.openweathermap.org/data/2.5/weather?appid=1205305b6503b5009fc8c436728e1ea8&q=copiapo&units=metric
# Processing Record:Record Number 533; CityName:pauini; QueryURL=http://api.openweathermap.org/data/2.5/weather?appid=1205305b6503b5009fc8c436728e1ea8&q=pauini&units=metric
# Processing Record:Record Number 534; CityName:andra; QueryURL=http://api.openweathermap.org/data/2.5/weather?appid=1205305b6503b5009fc8c436728e1ea8&q=andra&units=metric
# Processing Record:Record Number 535; CityName:beyneu; QueryURL=http://api.openweathermap.org/data/2.5/weather?appid=1205305b6503b5009fc8c436728e1ea8&q=beyneu&units=metric
# Processing Record:Record Number 536; CityName:kuche; QueryURL=http://api.openweathermap.org/data/2.5/weather?appid=1205305b6503b5009fc8c436728e1ea8&q=kuche&units=metric
# NOT FOUND...Skipping Record Number 536; CityName:kuche
# Processing Record:Record Number 537; CityName:leningradskiy; QueryURL=http://api.openweathermap.org/data/2.5/weather?appid=1205305b6503b5009fc8c436728e1ea8&q=leningradskiy&units=metric
# Processing Record:Record Number 538; CityName:krasnyy kholm; QueryURL=http://api.openweathermap.org/data/2.5/weather?appid=1205305b6503b5009fc8c436728e1ea8&q=krasnyy kholm&units=metric
# Processing Record:Record Number 539; CityName:waipawa; QueryURL=http://api.openweathermap.org/data/2.5/weather?appid=1205305b6503b5009fc8c436728e1ea8&q=waipawa&units=metric
# Processing Record:Record Number 540; CityName:brazzaville; QueryURL=http://api.openweathermap.org/data/2.5/weather?appid=1205305b6503b5009fc8c436728e1ea8&q=brazzaville&units=metric
# Processing Record:Record Number 541; CityName:labuhan; QueryURL=http://api.openweathermap.org/data/2.5/weather?appid=1205305b6503b5009fc8c436728e1ea8&q=labuhan&units=metric
# Processing Record:Record Number 542; CityName:somerset east; QueryURL=http://api.openweathermap.org/data/2.5/weather?appid=1205305b6503b5009fc8c436728e1ea8&q=somerset east&units=metric
# Processing Record:Record Number 543; CityName:ziro; QueryURL=http://api.openweathermap.org/data/2.5/weather?appid=1205305b6503b5009fc8c436728e1ea8&q=ziro&units=metric
# Processing Record:Record Number 544; CityName:imbituba; QueryURL=http://api.openweathermap.org/data/2.5/weather?appid=1205305b6503b5009fc8c436728e1ea8&q=imbituba&units=metric
# Processing Record:Record Number 545; CityName:turiacu; QueryURL=http://api.openweathermap.org/data/2.5/weather?appid=1205305b6503b5009fc8c436728e1ea8&q=turiacu&units=metric
# Processing Record:Record Number 546; CityName:buzdyak; QueryURL=http://api.openweathermap.org/data/2.5/weather?appid=1205305b6503b5009fc8c436728e1ea8&q=buzdyak&units=metric
# Processing Record:Record Number 547; CityName:roald; QueryURL=http://api.openweathermap.org/data/2.5/weather?appid=1205305b6503b5009fc8c436728e1ea8&q=roald&units=metric
# Processing Record:Record Number 548; CityName:rameswaram; QueryURL=http://api.openweathermap.org/data/2.5/weather?appid=1205305b6503b5009fc8c436728e1ea8&q=rameswaram&units=metric
# Processing Record:Record Number 549; CityName:budogoshch; QueryURL=http://api.openweathermap.org/data/2.5/weather?appid=1205305b6503b5009fc8c436728e1ea8&q=budogoshch&units=metric
# Processing Record:Record Number 550; CityName:gigmoto; QueryURL=http://api.openweathermap.org/data/2.5/weather?appid=1205305b6503b5009fc8c436728e1ea8&q=gigmoto&units=metric
# Processing Record:Record Number 551; CityName:green river; QueryURL=http://api.openweathermap.org/data/2.5/weather?appid=1205305b6503b5009fc8c436728e1ea8&q=green river&units=metric
# Processing Record:Record Number 552; CityName:barra do garcas; QueryURL=http://api.openweathermap.org/data/2.5/weather?appid=1205305b6503b5009fc8c436728e1ea8&q=barra do garcas&units=metric
# Processing Record:Record Number 553; CityName:oistins; QueryURL=http://api.openweathermap.org/data/2.5/weather?appid=1205305b6503b5009fc8c436728e1ea8&q=oistins&units=metric
# Processing Record:Record Number 554; CityName:mana; QueryURL=http://api.openweathermap.org/data/2.5/weather?appid=1205305b6503b5009fc8c436728e1ea8&q=mana&units=metric
# Processing Record:Record Number 555; CityName:cervo; QueryURL=http://api.openweathermap.org/data/2.5/weather?appid=1205305b6503b5009fc8c436728e1ea8&q=cervo&units=metric
# Processing Record:Record Number 556; CityName:olafsvik; QueryURL=http://api.openweathermap.org/data/2.5/weather?appid=1205305b6503b5009fc8c436728e1ea8&q=olafsvik&units=metric
# NOT FOUND...Skipping Record Number 556; CityName:olafsvik
# Processing Record:Record Number 557; CityName:winsum; QueryURL=http://api.openweathermap.org/data/2.5/weather?appid=1205305b6503b5009fc8c436728e1ea8&q=winsum&units=metric
# Processing Record:Record Number 558; CityName:shingu; QueryURL=http://api.openweathermap.org/data/2.5/weather?appid=1205305b6503b5009fc8c436728e1ea8&q=shingu&units=metric
# Processing Record:Record Number 559; CityName:thalgau; QueryURL=http://api.openweathermap.org/data/2.5/weather?appid=1205305b6503b5009fc8c436728e1ea8&q=thalgau&units=metric
# Processing Record:Record Number 560; CityName:hurghada; QueryURL=http://api.openweathermap.org/data/2.5/weather?appid=1205305b6503b5009fc8c436728e1ea8&q=hurghada&units=metric
# NOT FOUND...Skipping Record Number 560; CityName:hurghada
# Processing Record:Record Number 561; CityName:ventspils; QueryURL=http://api.openweathermap.org/data/2.5/weather?appid=1205305b6503b5009fc8c436728e1ea8&q=ventspils&units=metric
# Processing Record:Record Number 562; CityName:lawrenceburg; QueryURL=http://api.openweathermap.org/data/2.5/weather?appid=1205305b6503b5009fc8c436728e1ea8&q=lawrenceburg&units=metric
# Processing Record:Record Number 563; CityName:borovoy; QueryURL=http://api.openweathermap.org/data/2.5/weather?appid=1205305b6503b5009fc8c436728e1ea8&q=borovoy&units=metric
# Processing Record:Record Number 564; CityName:alagoinhas; QueryURL=http://api.openweathermap.org/data/2.5/weather?appid=1205305b6503b5009fc8c436728e1ea8&q=alagoinhas&units=metric
# Processing Record:Record Number 565; CityName:brae; QueryURL=http://api.openweathermap.org/data/2.5/weather?appid=1205305b6503b5009fc8c436728e1ea8&q=brae&units=metric
# Processing Record:Record Number 566; CityName:elat; QueryURL=http://api.openweathermap.org/data/2.5/weather?appid=1205305b6503b5009fc8c436728e1ea8&q=elat&units=metric
# Processing Record:Record Number 567; CityName:azare; QueryURL=http://api.openweathermap.org/data/2.5/weather?appid=1205305b6503b5009fc8c436728e1ea8&q=azare&units=metric
# Processing Record:Record Number 568; CityName:santiago del estero; QueryURL=http://api.openweathermap.org/data/2.5/weather?appid=1205305b6503b5009fc8c436728e1ea8&q=santiago del estero&units=metric
# Processing Record:Record Number 569; CityName:victor harbor; QueryURL=http://api.openweathermap.org/data/2.5/weather?appid=1205305b6503b5009fc8c436728e1ea8&q=victor harbor&units=metric
# Processing Record:Record Number 570; CityName:puro; QueryURL=http://api.openweathermap.org/data/2.5/weather?appid=1205305b6503b5009fc8c436728e1ea8&q=puro&units=metric
# Processing Record:Record Number 571; CityName:nueve de julio; QueryURL=http://api.openweathermap.org/data/2.5/weather?appid=1205305b6503b5009fc8c436728e1ea8&q=nueve de julio&units=metric
# Processing Record:Record Number 572; CityName:svetlyy; QueryURL=http://api.openweathermap.org/data/2.5/weather?appid=1205305b6503b5009fc8c436728e1ea8&q=svetlyy&units=metric
# NOT FOUND...Skipping Record Number 572; CityName:svetlyy
# Processing Record:Record Number 573; CityName:andenes; QueryURL=http://api.openweathermap.org/data/2.5/weather?appid=1205305b6503b5009fc8c436728e1ea8&q=andenes&units=metric
# NOT FOUND...Skipping Record Number 573; CityName:andenes
# Processing Record:Record Number 574; CityName:petauke; QueryURL=http://api.openweathermap.org/data/2.5/weather?appid=1205305b6503b5009fc8c436728e1ea8&q=petauke&units=metric
# Processing Record:Record Number 575; CityName:kununurra; QueryURL=http://api.openweathermap.org/data/2.5/weather?appid=1205305b6503b5009fc8c436728e1ea8&q=kununurra&units=metric
# Processing Record:Record Number 576; CityName:dangara; QueryURL=http://api.openweathermap.org/data/2.5/weather?appid=1205305b6503b5009fc8c436728e1ea8&q=dangara&units=metric
# Processing Record:Record Number 577; CityName:hanyang; QueryURL=http://api.openweathermap.org/data/2.5/weather?appid=1205305b6503b5009fc8c436728e1ea8&q=hanyang&units=metric
# Processing Record:Record Number 578; CityName:bol; QueryURL=http://api.openweathermap.org/data/2.5/weather?appid=1205305b6503b5009fc8c436728e1ea8&q=bol&units=metric
# Processing Record:Record Number 579; CityName:les cayes; QueryURL=http://api.openweathermap.org/data/2.5/weather?appid=1205305b6503b5009fc8c436728e1ea8&q=les cayes&units=metric
# Processing Record:Record Number 580; CityName:caravelas; QueryURL=http://api.openweathermap.org/data/2.5/weather?appid=1205305b6503b5009fc8c436728e1ea8&q=caravelas&units=metric
# Processing Record:Record Number 581; CityName:the pas; QueryURL=http://api.openweathermap.org/data/2.5/weather?appid=1205305b6503b5009fc8c436728e1ea8&q=the pas&units=metric
# Processing Record:Record Number 582; CityName:minas novas; QueryURL=http://api.openweathermap.org/data/2.5/weather?appid=1205305b6503b5009fc8c436728e1ea8&q=minas novas&units=metric
# Processing Record:Record Number 583; CityName:aklavik; QueryURL=http://api.openweathermap.org/data/2.5/weather?appid=1205305b6503b5009fc8c436728e1ea8&q=aklavik&units=metric
# Processing Record:Record Number 584; CityName:saint anthony; QueryURL=http://api.openweathermap.org/data/2.5/weather?appid=1205305b6503b5009fc8c436728e1ea8&q=saint anthony&units=metric
# Processing Record:Record Number 585; CityName:gazanjyk; QueryURL=http://api.openweathermap.org/data/2.5/weather?appid=1205305b6503b5009fc8c436728e1ea8&q=gazanjyk&units=metric
# Processing Record:Record Number 586; CityName:vila; QueryURL=http://api.openweathermap.org/data/2.5/weather?appid=1205305b6503b5009fc8c436728e1ea8&q=vila&units=metric
# Processing Record:Record Number 587; CityName:lunino; QueryURL=http://api.openweathermap.org/data/2.5/weather?appid=1205305b6503b5009fc8c436728e1ea8&q=lunino&units=metric
# Processing Record:Record Number 588; CityName:mudgee; QueryURL=http://api.openweathermap.org/data/2.5/weather?appid=1205305b6503b5009fc8c436728e1ea8&q=mudgee&units=metric
# Processing Record:Record Number 589; CityName:comodoro rivadavia; QueryURL=http://api.openweathermap.org/data/2.5/weather?appid=1205305b6503b5009fc8c436728e1ea8&q=comodoro rivadavia&units=metric
# Processing Record:Record Number 590; CityName:camana; QueryURL=http://api.openweathermap.org/data/2.5/weather?appid=1205305b6503b5009fc8c436728e1ea8&q=camana&units=metric
# NOT FOUND...Skipping Record Number 590; CityName:camana
# Processing Record:Record Number 591; CityName:bose; QueryURL=http://api.openweathermap.org/data/2.5/weather?appid=1205305b6503b5009fc8c436728e1ea8&q=bose&units=metric
# Processing Record:Record Number 592; CityName:djambala; QueryURL=http://api.openweathermap.org/data/2.5/weather?appid=1205305b6503b5009fc8c436728e1ea8&q=djambala&units=metric
# Processing Record:Record Number 593; CityName:riverton; QueryURL=http://api.openweathermap.org/data/2.5/weather?appid=1205305b6503b5009fc8c436728e1ea8&q=riverton&units=metric
# Processing Record:Record Number 594; CityName:puerto carreno; QueryURL=http://api.openweathermap.org/data/2.5/weather?appid=1205305b6503b5009fc8c436728e1ea8&q=puerto carreno&units=metric
# Processing Record:Record Number 595; CityName:luau; QueryURL=http://api.openweathermap.org/data/2.5/weather?appid=1205305b6503b5009fc8c436728e1ea8&q=luau&units=metric
# Processing Record:Record Number 596; CityName:fort nelson; QueryURL=http://api.openweathermap.org/data/2.5/weather?appid=1205305b6503b5009fc8c436728e1ea8&q=fort nelson&units=metric
# Processing Record:Record Number 597; CityName:cairns; QueryURL=http://api.openweathermap.org/data/2.5/weather?appid=1205305b6503b5009fc8c436728e1ea8&q=cairns&units=metric
# Processing Record:Record Number 598; CityName:pangai; QueryURL=http://api.openweathermap.org/data/2.5/weather?appid=1205305b6503b5009fc8c436728e1ea8&q=pangai&units=metric
# Processing Record:Record Number 599; CityName:roma; QueryURL=http://api.openweathermap.org/data/2.5/weather?appid=1205305b6503b5009fc8c436728e1ea8&q=roma&units=metric
# Processing Record:Record Number 600; CityName:basco; QueryURL=http://api.openweathermap.org/data/2.5/weather?appid=1205305b6503b5009fc8c436728e1ea8&q=basco&units=metric
# Processing Record:Record Number 601; CityName:chunoyar; QueryURL=http://api.openweathermap.org/data/2.5/weather?appid=1205305b6503b5009fc8c436728e1ea8&q=chunoyar&units=metric
# Processing Record:Record Number 602; CityName:plouzane; QueryURL=http://api.openweathermap.org/data/2.5/weather?appid=1205305b6503b5009fc8c436728e1ea8&q=plouzane&units=metric

# %%
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | lompoc
# Processing Record 2 of Set 1 | klaksvik
# Processing Record 3 of Set 1 | bisignano
# Processing Record 4 of Set 1 | bengkulu
# City not found. Skipping...
# Processing Record 5 of Set 1 | hilo
# Processing Record 6 of Set 1 | rikitea
# Processing Record 7 of Set 1 | ahipara
# Processing Record 8 of Set 1 | lebu
# Processing Record 9 of Set 1 | hamilton
# Processing Record 10 of Set 1 | castro
# Processing Record 11 of Set 1 | ashland
# Processing Record 12 of Set 1 | ushuaia
# Processing Record 13 of Set 1 | haines junction
# Processing Record 14 of Set 1 | punta arenas
# Processing Record 15 of Set 1 | salalah
# Processing Record 16 of Set 1 | port macquarie
# Processing Record 17 of Set 1 | mataura
# Processing Record 18 of Set 1 | saint-philippe
# Processing Record 19 of Set 1 | kaitangata
# Processing Record 20 of Set 1 | souillac
# Processing Record 21 of Set 1 | srednekolymsk
# Processing Record 22 of Set 1 | busselton
# Processing Record 23 of Set 1 | severo-kurilsk
# Processing Record 24 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 25 of Set 1 | ivaipora
# City not found. Skipping...
# Processing Record 26 of Set 1 | cape town
# Processing Record 27 of Set 1 | ambilobe
# Processing Record 28 of Set 1 | yellowknife
# Processing Record 29 of Set 1 | talnakh
# Processing Record 30 of Set 1 | namatanai
# Processing Record 31 of Set 1 | scottsburgh
# City not found. Skipping...
# Processing Record 32 of Set 1 | leningradskiy
# Processing Record 33 of Set 1 | khormuj
# City not found. Skipping...
# Processing Record 34 of Set 1 | kodiak
# Processing Record 35 of Set 1 | muros
# Processing Record 36 of Set 1 | tamandare
# Processing Record 37 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 38 of Set 1 | albany
# Processing Record 39 of Set 1 | lumut
# Processing Record 40 of Set 1 | sukumo
# Processing Record 41 of Set 1 | chapais
# Processing Record 42 of Set 1 | khatanga
# Processing Record 43 of Set 1 | ordzhonikidze
# Processing Record 44 of Set 1 | jiangyou
# Processing Record 45 of Set 1 | ancud
# Processing Record 46 of Set 1 | vila franca do campo
# Processing Record 47 of Set 1 | shchelkun
# Processing Record 48 of Set 1 | vanimo
# Processing Record 49 of Set 1 | kalmanhaza
# Processing Record 50 of Set 1 | butaritari
# Processing Record 0 of Set 2 | codrington
# Processing Record 1 of Set 2 | ayolas
# Processing Record 2 of Set 2 | kapaa
# Processing Record 3 of Set 2 | east london
# Processing Record 4 of Set 2 | vaini
# Processing Record 5 of Set 2 | tessalit
# Processing Record 6 of Set 2 | panguna
# Processing Record 7 of Set 2 | cockburn town
# Processing Record 8 of Set 2 | valerianovsk
# Processing Record 9 of Set 2 | tingrela
# City not found. Skipping...
# Processing Record 10 of Set 2 | novobirilyussy
# Processing Record 11 of Set 2 | krasnoborsk
# Processing Record 12 of Set 2 | mar del plata
# Processing Record 13 of Set 2 | new norfolk
# Processing Record 14 of Set 2 | khonuu
# City not found. Skipping...
# Processing Record 15 of Set 2 | vila do maio
# Processing Record 16 of Set 2 | dikson
# Processing Record 17 of Set 2 | tsihombe
# City not found. Skipping...
# Processing Record 18 of Set 2 | toliary
# City not found. Skipping...
# Processing Record 19 of Set 2 | kazalinsk
# City not found. Skipping...
# Processing Record 20 of Set 2 | livani
# Processing Record 21 of Set 2 | urucui
# Processing Record 22 of Set 2 | ribeira grande
# Processing Record 23 of Set 2 | qaanaaq
# Processing Record 24 of Set 2 | sentyabrskiy
# City not found. Skipping...
# Processing Record 25 of Set 2 | tuatapere
# Processing Record 26 of Set 2 | bocaiuva
# Processing Record 27 of Set 2 | jiexiu
# Processing Record 28 of Set 2 | quelimane
# Processing Record 29 of Set 2 | rujewa
# Processing Record 30 of Set 2 | cherskiy
# Processing Record 31 of Set 2 | port elizabeth
# Processing Record 32 of Set 2 | yanchukan
# City not found. Skipping...
# Processing Record 33 of Set 2 | fortuna
# Processing Record 34 of Set 2 | belyy yar
# Processing Record 35 of Set 2 | venezuela
# Processing Record 36 of Set 2 | bambous virieux
# Processing Record 37 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 38 of Set 2 | barrow
# Processing Record 39 of Set 2 | mitsamiouli
# Processing Record 40 of Set 2 | hunza
# City not found. Skipping...
# Processing Record 41 of Set 2 | bunia
# Processing Record 42 of Set 2 | boa vista
# Processing Record 43 of Set 2 | kudahuvadhoo
# Processing Record 44 of Set 2 | mys shmidta
# City not found. Skipping...
# Processing Record 45 of Set 2 | bluff
# Processing Record 46 of Set 2 | okhotsk
# Processing Record 47 of Set 2 | muzaffarabad
# Processing Record 48 of Set 2 | avarua
# Processing Record 49 of Set 2 | esperance
# Processing Record 0 of Set 3 | arenapolis
# Processing Record 1 of Set 3 | tuktoyaktuk
# Processing Record 2 of Set 3 | nemuro
# Processing Record 3 of Set 3 | attawapiskat
# City not found. Skipping...
# Processing Record 4 of Set 3 | rio gallegos
# Processing Record 5 of Set 3 | svetlaya
# Processing Record 6 of Set 3 | nome
# Processing Record 7 of Set 3 | caravelas
# Processing Record 8 of Set 3 | karamea
# City not found. Skipping...
# Processing Record 9 of Set 3 | mandalgovi
# Processing Record 10 of Set 3 | carnarvon
# Processing Record 11 of Set 3 | atuona
# Processing Record 12 of Set 3 | pemangkat
# City not found. Skipping...
# Processing Record 13 of Set 3 | karaul
# City not found. Skipping...
# Processing Record 14 of Set 3 | qiqihar
# Processing Record 15 of Set 3 | cabo san lucas
# Processing Record 16 of Set 3 | jamestown
# Processing Record 17 of Set 3 | komsomolskiy
# Processing Record 18 of Set 3 | arraial do cabo
# Processing Record 19 of Set 3 | tiksi
# Processing Record 20 of Set 3 | amnat charoen
# Processing Record 21 of Set 3 | provideniya
# Processing Record 22 of Set 3 | luang prabang
# Processing Record 23 of Set 3 | hami
# Processing Record 24 of Set 3 | saskylakh
# Processing Record 25 of Set 3 | kyren
# Processing Record 26 of Set 3 | yuanping
# Processing Record 27 of Set 3 | dukat
# Processing Record 28 of Set 3 | barentsburg
# City not found. Skipping...
# Processing Record 29 of Set 3 | chuy
# Processing Record 30 of Set 3 | dorfen
# Processing Record 31 of Set 3 | ayan
# Processing Record 32 of Set 3 | port alfred
# Processing Record 33 of Set 3 | nanortalik
# Processing Record 34 of Set 3 | nizhneyansk
# City not found. Skipping...
# Processing Record 35 of Set 3 | vertientes
# Processing Record 36 of Set 3 | charters towers
# Processing Record 37 of Set 3 | nenjiang
# Processing Record 38 of Set 3 | hermanus
# Processing Record 39 of Set 3 | saleaula
# City not found. Skipping...
# Processing Record 40 of Set 3 | puerto del rosario
# Processing Record 41 of Set 3 | husavik
# Processing Record 42 of Set 3 | maldonado
# Processing Record 43 of Set 3 | bintulu
# Processing Record 44 of Set 3 | warqla
# City not found. Skipping...
# Processing Record 45 of Set 3 | luderitz
# Processing Record 46 of Set 3 | vardo
# Processing Record 47 of Set 3 | faanui
# Processing Record 48 of Set 3 | muzhi
# Processing Record 49 of Set 3 | zhangye
# Processing Record 0 of Set 4 | nouadhibou
# Processing Record 1 of Set 4 | oussouye
# Processing Record 2 of Set 4 | agaro
# Processing Record 3 of Set 4 | samusu
# City not found. Skipping...
# Processing Record 4 of Set 4 | tasiilaq
# Processing Record 5 of Set 4 | amderma
# City not found. Skipping...
# Processing Record 6 of Set 4 | bathsheba
# Processing Record 7 of Set 4 | pacific grove
# Processing Record 8 of Set 4 | half moon bay
# Processing Record 9 of Set 4 | goderich
# Processing Record 10 of Set 4 | severnyy
# City not found. Skipping...
# Processing Record 11 of Set 4 | erenhot
# Processing Record 12 of Set 4 | hasaki
# Processing Record 13 of Set 4 | agadez
# Processing Record 14 of Set 4 | hobart
# Processing Record 15 of Set 4 | drummondville
# Processing Record 16 of Set 4 | selfoss
# Processing Record 17 of Set 4 | carman
# Processing Record 18 of Set 4 | kurumkan
# Processing Record 19 of Set 4 | rawson
# Processing Record 20 of Set 4 | osakarovka
# Processing Record 21 of Set 4 | sitka
# Processing Record 22 of Set 4 | pec
# Processing Record 23 of Set 4 | nacala
# Processing Record 24 of Set 4 | vaitupu
# City not found. Skipping...
# Processing Record 25 of Set 4 | ewo
# Processing Record 26 of Set 4 | alihe
# Processing Record 27 of Set 4 | felipe carrillo puerto
# Processing Record 28 of Set 4 | sept-iles
# Processing Record 29 of Set 4 | anzio
# Processing Record 30 of Set 4 | abeche
# Processing Record 31 of Set 4 | chokurdakh
# Processing Record 32 of Set 4 | sao filipe
# Processing Record 33 of Set 4 | yatou
# Processing Record 34 of Set 4 | pangkalanbuun
# Processing Record 35 of Set 4 | namibe
# Processing Record 36 of Set 4 | caltagirone
# Processing Record 37 of Set 4 | araguacu
# City not found. Skipping...
# Processing Record 38 of Set 4 | atuntaqui
# Processing Record 39 of Set 4 | marshfield
# Processing Record 40 of Set 4 | saint-joseph
# Processing Record 41 of Set 4 | chambas
# Processing Record 42 of Set 4 | mahebourg
# Processing Record 43 of Set 4 | abadan
# Processing Record 44 of Set 4 | lagoa
# Processing Record 45 of Set 4 | axim
# Processing Record 46 of Set 4 | sioux lookout
# Processing Record 47 of Set 4 | voh
# Processing Record 48 of Set 4 | puerto ayora
# Processing Record 49 of Set 4 | sinnamary
# Processing Record 0 of Set 5 | duz
# City not found. Skipping...
# Processing Record 1 of Set 5 | upernavik
# Processing Record 2 of Set 5 | port hardy
# Processing Record 3 of Set 5 | vieste
# Processing Record 4 of Set 5 | dalvik
# Processing Record 5 of Set 5 | tual
# Processing Record 6 of Set 5 | novopokrovka
# Processing Record 7 of Set 5 | soyo
# Processing Record 8 of Set 5 | broken hill
# Processing Record 9 of Set 5 | columbia
# Processing Record 10 of Set 5 | sao joao da barra
# Processing Record 11 of Set 5 | lumphat
# Processing Record 12 of Set 5 | ciudad bolivar
# Processing Record 13 of Set 5 | san quintin
# Processing Record 14 of Set 5 | bredasdorp
# Processing Record 15 of Set 5 | torbay
# Processing Record 16 of Set 5 | hithadhoo
# Processing Record 17 of Set 5 | tabarqah
# City not found. Skipping...
# Processing Record 18 of Set 5 | vila velha
# Processing Record 19 of Set 5 | samaniego
# Processing Record 20 of Set 5 | kruisfontein
# Processing Record 21 of Set 5 | tumannyy
# City not found. Skipping...
# Processing Record 22 of Set 5 | dunedin
# Processing Record 23 of Set 5 | nikolskoye
# Processing Record 24 of Set 5 | geraldton
# Processing Record 25 of Set 5 | sarangani
# Processing Record 26 of Set 5 | bontang
# Processing Record 27 of Set 5 | jacareacanga
# Processing Record 28 of Set 5 | palabuhanratu
# City not found. Skipping...
# Processing Record 29 of Set 5 | raudeberg
# Processing Record 30 of Set 5 | terrenate
# Processing Record 31 of Set 5 | vao
# Processing Record 32 of Set 5 | asau
# City not found. Skipping...
# Processing Record 33 of Set 5 | hovd
# Processing Record 34 of Set 5 | bure
# Processing Record 35 of Set 5 | ranot
# Processing Record 36 of Set 5 | barawe
# City not found. Skipping...
# Processing Record 37 of Set 5 | merauke
# Processing Record 38 of Set 5 | prichard
# Processing Record 39 of Set 5 | gravelbourg
# Processing Record 40 of Set 5 | searcy
# Processing Record 41 of Set 5 | chagda
# City not found. Skipping...
# Processing Record 42 of Set 5 | victoria
# Processing Record 43 of Set 5 | sisimiut
# Processing Record 44 of Set 5 | trelew
# Processing Record 45 of Set 5 | aban
# City not found. Skipping...
# Processing Record 46 of Set 5 | vakhrushev
# Processing Record 47 of Set 5 | pierre
# Processing Record 48 of Set 5 | ilulissat
# Processing Record 49 of Set 5 | lorengau
# Processing Record 0 of Set 6 | mokrousovo
# Processing Record 1 of Set 6 | baltay
# Processing Record 2 of Set 6 | kainantu
# Processing Record 3 of Set 6 | goulburn
# Processing Record 4 of Set 6 | lincoln
# Processing Record 5 of Set 6 | harnosand
# Processing Record 6 of Set 6 | camana
# City not found. Skipping...
# Processing Record 7 of Set 6 | pleshanovo
# Processing Record 8 of Set 6 | ostrovnoy
# Processing Record 9 of Set 6 | porto novo
# Processing Record 10 of Set 6 | kawana waters
# City not found. Skipping...
# Processing Record 11 of Set 6 | quatre cocos
# Processing Record 12 of Set 6 | marzuq
# Processing Record 13 of Set 6 | prince george
# Processing Record 14 of Set 6 | grand river south east
# City not found. Skipping...
# Processing Record 15 of Set 6 | sorsk
# Processing Record 16 of Set 6 | port blair
# Processing Record 17 of Set 6 | shihezi
# Processing Record 18 of Set 6 | coffs harbour
# Processing Record 19 of Set 6 | rasova
# Processing Record 20 of Set 6 | dingle
# Processing Record 21 of Set 6 | la primavera
# Processing Record 22 of Set 6 | tezu
# Processing Record 23 of Set 6 | qasigiannguit
# Processing Record 24 of Set 6 | westport
# Processing Record 25 of Set 6 | peleduy
# Processing Record 26 of Set 6 | yei
# City not found. Skipping...
# Processing Record 27 of Set 6 | dakar
# Processing Record 28 of Set 6 | temaraia
# City not found. Skipping...
# Processing Record 29 of Set 6 | pisco
# Processing Record 30 of Set 6 | buzuluk
# Processing Record 31 of Set 6 | jahrom
# City not found. Skipping...
# Processing Record 32 of Set 6 | ponferrada
# Processing Record 33 of Set 6 | kaeo
# Processing Record 34 of Set 6 | chimbote
# Processing Record 35 of Set 6 | rocha
# Processing Record 36 of Set 6 | kurkino
# Processing Record 37 of Set 6 | kavaratti
# Processing Record 38 of Set 6 | puri
# Processing Record 39 of Set 6 | maues
# Processing Record 40 of Set 6 | kapit
# Processing Record 41 of Set 6 | sinegorye
# Processing Record 42 of Set 6 | thompson
# Processing Record 43 of Set 6 | kadykchan
# City not found. Skipping...
# Processing Record 44 of Set 6 | itaueira
# Processing Record 45 of Set 6 | georgetown
# Processing Record 46 of Set 6 | parana
# Processing Record 47 of Set 6 | govindgarh
# Processing Record 48 of Set 6 | laguna
# Processing Record 49 of Set 6 | tura
# Processing Record 0 of Set 7 | nhulunbuy
# Processing Record 1 of Set 7 | buala
# Processing Record 2 of Set 7 | ngunguru
# Processing Record 3 of Set 7 | abu zabad
# Processing Record 4 of Set 7 | katete
# Processing Record 5 of Set 7 | flin flon
# Processing Record 6 of Set 7 | fayaoue
# Processing Record 7 of Set 7 | umzimvubu
# City not found. Skipping...
# Processing Record 8 of Set 7 | port hedland
# Processing Record 9 of Set 7 | omsukchan
# Processing Record 10 of Set 7 | la asuncion
# Processing Record 11 of Set 7 | hambantota
# Processing Record 12 of Set 7 | matagami
# Processing Record 13 of Set 7 | palmer
# Processing Record 14 of Set 7 | dzhebariki-khaya
# Processing Record 15 of Set 7 | shitanjing
# Processing Record 16 of Set 7 | ixtapa
# Processing Record 17 of Set 7 | bethel
# Processing Record 18 of Set 7 | khani
# Processing Record 19 of Set 7 | saint george
# Processing Record 20 of Set 7 | whitehorse
# Processing Record 21 of Set 7 | isiolo
# Processing Record 22 of Set 7 | sao paulo de olivenca
# Processing Record 23 of Set 7 | buckeye
# Processing Record 24 of Set 7 | wewak
# Processing Record 25 of Set 7 | huarmey
# Processing Record 26 of Set 7 | satitoa
# City not found. Skipping...
# Processing Record 27 of Set 7 | la libertad
# Processing Record 28 of Set 7 | norman wells
# Processing Record 29 of Set 7 | dicabisagan
# Processing Record 30 of Set 7 | kavieng
# Processing Record 31 of Set 7 | wladyslawowo
# Processing Record 32 of Set 7 | kemin
# Processing Record 33 of Set 7 | coolum beach
# Processing Record 34 of Set 7 | rosetta
# Processing Record 35 of Set 7 | bermeo
# Processing Record 36 of Set 7 | turtas
# Processing Record 37 of Set 7 | mount gambier
# Processing Record 38 of Set 7 | key west
# Processing Record 39 of Set 7 | aklavik
# Processing Record 40 of Set 7 | tikapur
# Processing Record 41 of Set 7 | oranjestad
# Processing Record 42 of Set 7 | calvinia
# Processing Record 43 of Set 7 | kahului
# Processing Record 44 of Set 7 | gaziantep
# Processing Record 45 of Set 7 | port augusta
# Processing Record 46 of Set 7 | turukhansk
# Processing Record 47 of Set 7 | roma
# Processing Record 48 of Set 7 | buraydah
# Processing Record 49 of Set 7 | andenes
# City not found. Skipping...
# Processing Record 0 of Set 8 | coihaique
# Processing Record 1 of Set 8 | surt
# Processing Record 2 of Set 8 | rawannawi
# City not found. Skipping...
# Processing Record 3 of Set 8 | nanjangud
# Processing Record 4 of Set 8 | saravan
# Processing Record 5 of Set 8 | penzance
# Processing Record 6 of Set 8 | mehamn
# Processing Record 7 of Set 8 | baherden
# Processing Record 8 of Set 8 | minbu
# Processing Record 9 of Set 8 | hamina
# Processing Record 10 of Set 8 | mackay
# Processing Record 11 of Set 8 | omaruru
# Processing Record 12 of Set 8 | roald
# Processing Record 13 of Set 8 | tashtyp
# Processing Record 14 of Set 8 | kyra
# City not found. Skipping...
# Processing Record 15 of Set 8 | walvis bay
# Processing Record 16 of Set 8 | kloulklubed
# Processing Record 17 of Set 8 | le port
# Processing Record 18 of Set 8 | hokitika
# Processing Record 19 of Set 8 | guapi
# Processing Record 20 of Set 8 | manyana
# Processing Record 21 of Set 8 | airai
# Processing Record 22 of Set 8 | wajid
# Processing Record 23 of Set 8 | mumford
# Processing Record 24 of Set 8 | labuhan
# Processing Record 25 of Set 8 | sabang
# Processing Record 26 of Set 8 | batagay-alyta
# Processing Record 27 of Set 8 | ambodifototra
# City not found. Skipping...
# Processing Record 28 of Set 8 | gouyave
# Processing Record 29 of Set 8 | avera
# Processing Record 30 of Set 8 | zonguldak
# Processing Record 31 of Set 8 | tokur
# Processing Record 32 of Set 8 | pyay
# Processing Record 33 of Set 8 | ulladulla
# Processing Record 34 of Set 8 | grand-santi
# Processing Record 35 of Set 8 | urusha
# Processing Record 36 of Set 8 | lata
# Processing Record 37 of Set 8 | anar darreh
# City not found. Skipping...
# Processing Record 38 of Set 8 | tazovskiy
# Processing Record 39 of Set 8 | kefamenanu
# Processing Record 40 of Set 8 | agva
# City not found. Skipping...
# Processing Record 41 of Set 8 | kysyl-syr
# Processing Record 42 of Set 8 | wajima
# Processing Record 43 of Set 8 | kargopol
# Processing Record 44 of Set 8 | tubruq
# City not found. Skipping...
# Processing Record 45 of Set 8 | ovalle
# Processing Record 46 of Set 8 | wadi musa
# Processing Record 47 of Set 8 | iguape
# Processing Record 48 of Set 8 | san juan
# Processing Record 49 of Set 8 | vinh
# Processing Record 0 of Set 9 | kuminskiy
# Processing Record 1 of Set 9 | samalaeulu
# City not found. Skipping...
# Processing Record 2 of Set 9 | honningsvag
# Processing Record 3 of Set 9 | harper
# Processing Record 4 of Set 9 | batasan
# Processing Record 5 of Set 9 | yumen
# Processing Record 6 of Set 9 | tutoia
# Processing Record 7 of Set 9 | tazmalt
# Processing Record 8 of Set 9 | lavrentiya
# Processing Record 9 of Set 9 | sarmanovo
# Processing Record 10 of Set 9 | edgewater
# Processing Record 11 of Set 9 | gushikawa
# Processing Record 12 of Set 9 | kalmunai
# Processing Record 13 of Set 9 | houma
# Processing Record 14 of Set 9 | vila
# Processing Record 15 of Set 9 | umba
# Processing Record 16 of Set 9 | pevek
# Processing Record 17 of Set 9 | adrar
# Processing Record 18 of Set 9 | termiz
# Processing Record 19 of Set 9 | luanda
# Processing Record 20 of Set 9 | maniitsoq
# Processing Record 21 of Set 9 | yuncheng
# Processing Record 22 of Set 9 | port shepstone
# Processing Record 23 of Set 9 | truth or consequences
# Processing Record 24 of Set 9 | acapulco
# Processing Record 25 of Set 9 | necochea
# Processing Record 26 of Set 9 | broome
# Processing Record 27 of Set 9 | laredo
# Processing Record 28 of Set 9 | paradwip
# City not found. Skipping...
# Processing Record 29 of Set 9 | fort smith
# Processing Record 30 of Set 9 | comodoro rivadavia
# Processing Record 31 of Set 9 | ferme-neuve
# Processing Record 32 of Set 9 | dengzhou
# Processing Record 33 of Set 9 | kamennogorsk
# Processing Record 34 of Set 9 | padang
# Processing Record 35 of Set 9 | sorvag
# City not found. Skipping...
# Processing Record 36 of Set 9 | sorland
# Processing Record 37 of Set 9 | huangchuan
# Processing Record 38 of Set 9 | alofi
# Processing Record 39 of Set 9 | sur
# Processing Record 40 of Set 9 | tocopilla
# Processing Record 41 of Set 9 | rudbar
# City not found. Skipping...
# Processing Record 42 of Set 9 | galesong
# Processing Record 43 of Set 9 | paamiut
# Processing Record 44 of Set 9 | narsaq
# Processing Record 45 of Set 9 | sungaipenuh
# Processing Record 46 of Set 9 | papara
# Processing Record 47 of Set 9 | kuche
# City not found. Skipping...
# Processing Record 48 of Set 9 | isangel
# Processing Record 49 of Set 9 | kamyshlov
# Processing Record 0 of Set 10 | ponta do sol
# Processing Record 1 of Set 10 | lengshuitan
# Processing Record 2 of Set 10 | thinadhoo
# Processing Record 3 of Set 10 | saint anthony
# Processing Record 4 of Set 10 | yulara
# Processing Record 5 of Set 10 | kokopo
# Processing Record 6 of Set 10 | iqaluit
# Processing Record 7 of Set 10 | longyearbyen
# Processing Record 8 of Set 10 | los llanos de aridane
# Processing Record 9 of Set 10 | hayden
# Processing Record 10 of Set 10 | erzurum
# Processing Record 11 of Set 10 | bonthe
# Processing Record 12 of Set 10 | ketchikan
# Processing Record 13 of Set 10 | barkhan
# Processing Record 14 of Set 10 | euclides da cunha
# Processing Record 15 of Set 10 | sanghar
# Processing Record 16 of Set 10 | te anau
# Processing Record 17 of Set 10 | valleyview
# Processing Record 18 of Set 10 | cidreira
# Processing Record 19 of Set 10 | banda aceh
# Processing Record 20 of Set 10 | tagusao
# Processing Record 21 of Set 10 | terrace
# Processing Record 22 of Set 10 | el chichicaste
# Processing Record 23 of Set 10 | gberia fotombu
# Processing Record 24 of Set 10 | ranir bazar
# Processing Record 25 of Set 10 | grindsted
# Processing Record 26 of Set 10 | katsuura
# Processing Record 27 of Set 10 | qaqortoq
# Processing Record 28 of Set 10 | pontes e lacerda
# Processing Record 29 of Set 10 | bata
# Processing Record 30 of Set 10 | kingston
# Processing Record 31 of Set 10 | aleksandrovka
# Processing Record 32 of Set 10 | vostok
# Processing Record 33 of Set 10 | puerto madryn
# Processing Record 34 of Set 10 | yuzhnyy
# Processing Record 35 of Set 10 | bulungu
# Processing Record 36 of Set 10 | kollam
# Processing Record 37 of Set 10 | progreso
# Processing Record 38 of Set 10 | visby
# Processing Record 39 of Set 10 | ilebo
# Processing Record 40 of Set 10 | ajdabiya
# Processing Record 41 of Set 10 | maine-soroa
# Processing Record 42 of Set 10 | sayreville
# Processing Record 43 of Set 10 | palana
# Processing Record 44 of Set 10 | acajutiba
# Processing Record 45 of Set 10 | lakatoro
# Processing Record 46 of Set 10 | solsvik
# City not found. Skipping...
# Processing Record 47 of Set 10 | lakes entrance
# Processing Record 48 of Set 10 | ludza
# Processing Record 49 of Set 10 | zvishavane
# Processing Record 0 of Set 11 | mao
# Processing Record 1 of Set 11 | seaham
# Processing Record 2 of Set 11 | kaa-khem
# Processing Record 3 of Set 11 | grindavik
# Processing Record 4 of Set 11 | pangody
# Processing Record 5 of Set 11 | zhuzhou
# Processing Record 6 of Set 11 | clyde river
# Processing Record 7 of Set 11 | estelle
# Processing Record 8 of Set 11 | ulaanbaatar
# Processing Record 9 of Set 11 | victoria point
# Processing Record 10 of Set 11 | flores
# Processing Record 11 of Set 11 | cairns
# Processing Record 12 of Set 11 | beyneu
# Processing Record 13 of Set 11 | hoquiam
# Processing Record 14 of Set 11 | kurilsk
# Processing Record 15 of Set 11 | albuquerque
# Processing Record 16 of Set 11 | tomatlan
# Processing Record 17 of Set 11 | blackfoot
# Processing Record 18 of Set 11 | anito
# Processing Record 19 of Set 11 | meybod
# Processing Record 20 of Set 11 | muscat
# Processing Record 21 of Set 11 | san patricio
# Processing Record 22 of Set 11 | pali
# Processing Record 23 of Set 11 | atambua
# Processing Record 24 of Set 11 | mocambique
# City not found. Skipping...
# Processing Record 25 of Set 11 | kuytun
# Processing Record 26 of Set 11 | lamu
# Processing Record 27 of Set 11 | bandarbeyla
# Processing Record 28 of Set 11 | eenhana
# Processing Record 29 of Set 11 | newburn
# Processing Record 30 of Set 11 | changli
# Processing Record 31 of Set 11 | toowoomba
# Processing Record 32 of Set 11 | banjar
# Processing Record 33 of Set 11 | hohhot
# Processing Record 34 of Set 11 | debre birhan
# Processing Record 35 of Set 11 | nelson bay
# Processing Record 36 of Set 11 | sibu
# Processing Record 37 of Set 11 | black river
# City not found. Skipping...
# Processing Record 38 of Set 11 | thaba-tseka
# Processing Record 39 of Set 11 | hobyo
# Processing Record 40 of Set 11 | bela vista de goias
# Processing Record 41 of Set 11 | ugoofaaru
# Processing Record 42 of Set 11 | dali
# Processing Record 43 of Set 11 | kadaya
# Processing Record 44 of Set 11 | kensington
# Processing Record 45 of Set 11 | zhigansk
# Processing Record 46 of Set 11 | merritt island
# Processing Record 47 of Set 11 | yamada
# Processing Record 48 of Set 11 | kamenskoye
# City not found. Skipping...
# Processing Record 49 of Set 11 | baghdad
# Processing Record 0 of Set 12 | havre-saint-pierre
# Processing Record 1 of Set 12 | alta floresta
# Processing Record 2 of Set 12 | rio grande
# Processing Record 3 of Set 12 | wuwei
# Processing Record 4 of Set 12 | arman
# Processing Record 5 of Set 12 | salamiyah
# Processing Record 6 of Set 12 | vestmannaeyjar
# Processing Record 7 of Set 12 | dondo
# Processing Record 8 of Set 12 | gallup
# Processing Record 9 of Set 12 | micheweni
# Processing Record 10 of Set 12 | yanam
# Processing Record 11 of Set 12 | nipawin
# Processing Record 12 of Set 12 | jalu
# Processing Record 13 of Set 12 | brae
# Processing Record 14 of Set 12 | alappuzha
# City not found. Skipping...
# Processing Record 15 of Set 12 | leonidovo
# Processing Record 16 of Set 12 | krasnyy yar
# Processing Record 17 of Set 12 | nyimba
# Processing Record 18 of Set 12 | simao
# Processing Record 19 of Set 12 | kharsia
# Processing Record 20 of Set 12 | asekeyevo
# Processing Record 21 of Set 12 | haibowan
# City not found. Skipping...
# Processing Record 22 of Set 12 | les herbiers
# Processing Record 23 of Set 12 | bonavista
# Processing Record 24 of Set 12 | belaya gora
# Processing Record 25 of Set 12 | gao
# Processing Record 26 of Set 12 | yerbogachen
# Processing Record 27 of Set 12 | porechye-rybnoye
# Processing Record 28 of Set 12 | san andres
# Processing Record 29 of Set 12 | fairbanks
# Processing Record 30 of Set 12 | george
# Processing Record 31 of Set 12 | bradford
# Processing Record 32 of Set 12 | lago da pedra
# City not found. Skipping...
# Processing Record 33 of Set 12 | jomalig
# City not found. Skipping...
# Processing Record 34 of Set 12 | port lincoln
# Processing Record 35 of Set 12 | carutapera
# Processing Record 36 of Set 12 | awjilah
# Processing Record 37 of Set 12 | naryan-mar
# Processing Record 38 of Set 12 | la ronge
# Processing Record 39 of Set 12 | natal
# Processing Record 40 of Set 12 | nevsehir
# Processing Record 41 of Set 12 | turayf
# Processing Record 42 of Set 12 | temiscaming
# Processing Record 43 of Set 12 | gardan diwal
# City not found. Skipping...
# Processing Record 44 of Set 12 | kupang
# Processing Record 45 of Set 12 | port-cartier
# Processing Record 46 of Set 12 | storm lake
# Processing Record 47 of Set 12 | manokwari
# Processing Record 48 of Set 12 | julich
# Processing Record 49 of Set 12 | makung
# City not found. Skipping...
# Processing Record 0 of Set 13 | viedma
# Processing Record 1 of Set 13 | dolbeau
# City not found. Skipping...
# Processing Record 2 of Set 13 | sarkand
# Processing Record 3 of Set 13 | jhang
# Processing Record 4 of Set 13 | naze
# Processing Record 5 of Set 13 | zory
# Processing Record 6 of Set 13 | labuan
# Processing Record 7 of Set 13 | luwuk
# Processing Record 8 of Set 13 | sao felix do xingu
# Processing Record 9 of Set 13 | fonte boa
# Processing Record 10 of Set 13 | mahibadhoo
# Processing Record 11 of Set 13 | loukhi
# Processing Record 12 of Set 13 | mount isa
# Processing Record 13 of Set 13 | kargasok
# Processing Record 14 of Set 13 | mandera
# Processing Record 15 of Set 13 | praya
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
df=pd.DataFrame({'cityName':ctyfound,
                 'cloudiness':cloudiness,
                 'country':countries,
                 'date':dates,
                 'humidity':humidities,
                 'lat':lats,
                 'lng':lngs,
                 'maxTemp':maxTemps,
                 'windSpeed':windSpeeds,
                })

# %%
df.to_csv(output_data_file)

# %%
# Out:
#         City  Cloudiness Country        Date  Humidity    Lat     Lng  \
# 0     lompoc           1      US  1534984500        44  34.64 -120.46
# 1   klaksvik          92      FO  1534983600       100  62.23   -6.59
# 2  bisignano           0      IT  1534981800        88  39.50   16.27
# 3       hilo          90      US  1534984860        90  19.71 -155.08
# 4    rikitea           8      PF  1534986579       100 -23.12 -134.97
#
#    Max Temp  Wind Speed
# 0     77.00       11.41
# 1     50.00       13.87
# 2     66.20        5.82
# 3     77.00        8.05
# 4     69.58       19.71

# %% [markdown]
# ### Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %%
date=str(date.today())

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %%
df.plot('lat','maxTemp',kind='scatter')
plt.xlabel('Latitude')
plt.ylabel('Max Temperature (F)')
plt.title(f'City Latitude vs Max Temperature {date}')
plt.savefig(f'City Latitude vs Max Temperature {date}.png')
plt.show()

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %%
df.plot('lat','humidity',kind='scatter')
plt.xlabel('Latitude')
plt.ylabel('Humidity (%)')
plt.ylim(bottom=-10,top=110)
plt.title(f'City Latitude vs Humidity {date}')
plt.savefig(f'City Latitude vs Humidity {date}.png')

plt.show()

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %%
df.plot('lat','cloudiness',kind='scatter')
plt.xlabel('Latitude')
plt.ylabel('Cloudiness (%)')
plt.title(f'City Latitude vs Cloudiness {date}')
plt.savefig(f'City Latitude vs Cludiness {date}.png')

plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
df.plot('lat','windSpeed',kind='scatter')
plt.xlabel('Latitude')
plt.ylabel('Wind Speed (mph)')
plt.title(f'City Latitude vs Wind Speed {date}')
plt.savefig(f'City Latitude vs WindSpeed {date}.png')

plt.show()

# %% [markdown]
# CONCLUSIONS
#
# The graph 'City Latitude vs Max Temperature' shows a none linear relationship correlation between the city latitud and the temperature. It´s not unreasonable to think that cities around the Equator from -40 to 40 degrees the temperatures remain hight compared to the cities outside this latitudes. To proof this hipotesis, statistical tests are required.
#
# From the Humidity, WindSpeed and Cloudiness, none clear relation with the Latitude can be described, we have cities from any latitude with high or low levels of Humidity, WindSpeed and Cloudiness. To perform a better assesment, statistical tests are required
